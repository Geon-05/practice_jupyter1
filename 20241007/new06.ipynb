# %%
pwd
# Out:
# 'C:\\Users\\go121\\practice_jupyter\\py\\데이터분석 및 시각화\\API자료수집\\05네이버API'

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
import json
import pandas as pd

client_id = "sINqNPstJrYv4dDyStMK"
client_secret = "SKpquTbQWh"

def blog(query,start=1,display=100):
    res = []
    while display>0:
        if display > 100:
            base_url = 'https://openapi.naver.com/v1/search/blog'
            p = {
                'query':query,
                'display':100,
                'start':start
            }
        else :
            base_url = 'https://openapi.naver.com/v1/search/blog'
            p = {
                'query':query,
                'display':display,
                'start':start
            }
        enc_params = urllib.parse.urlencode(p)
        url = f'{base_url}?{enc_params}'
        
        request = urllib.request.Request(url)
        request.add_header("X-Naver-Client-Id",client_id)
        request.add_header("X-Naver-Client-Secret",client_secret)
        response = urllib.request.urlopen(request)
        rescode = response.getcode()
        if(rescode==200):
            response_body = response.read()
            res_json = json.loads(response_body)
            df = pd.DataFrame(res_json['items'])
            res.append(df)
        else:
            print("Error Code:" + rescode)
            
        display -= 100
        start +=100
        
    res_df = pd.concat(res, ignore_index=True)
    return res_df

blog('스타벅스', display=200)
# Out:
#                                             title  \
# 0               장충동 <b>스타벅스</b> 장충라운지 R점 주차 및 웨이팅
# 1               <b>스타벅스</b> 10월 가을 신메뉴 마롱 헤이즐넛 라떼
# 2                  <b>스타벅스</b> 버디패스 직접 써본 내돈내산 후기
# 3     <b>스타벅스</b> 플레이모빌 2024 2주차 버디 킴 빅터 매리 구매 후기
# 4             <b>스타벅스</b> 마롱 헤이즐넛 라떼 10월 신메뉴 맛 소감
# ..                                            ...
# 195    <b>스타벅스</b> 2024 헬로 키티 50주년 콜라보 텀블러 머그컵 인형
# 196  2024 <b>스타벅스</b> X 플레이모빌 콜라보 25주년 기념 피규어...
# 197            싱가포르 쇼핑, 싱가포르 <b>스타벅스</b> 굿즈 추천템 !
# 198               용인 고기리 <b>스타벅스</b> 계곡 주차 숲속의 카페
# 199            <b>스타벅스</b> 네스프레소 콜롬비아 싱글 오리진 캡슐커피
#
#                                                 link  \
# 0         https://blog.naver.com/luvzi-/223604647250
# 1     https://blog.naver.com/darkyoon85/223600579975
# 2        https://blog.naver.com/sohwa91/223603237044
# 3       https://blog.naver.com/kastro83/223609693616
# 4      https://blog.naver.com/lovableje/223598182604
# ..                                               ...
# 195    https://blog.naver.com/heena_mom/223588812160
# 196    https://blog.naver.com/heena_mom/223598207001
# 197  https://blog.naver.com/lovely_sine/223588301426
# 198      https://blog.naver.com/missto5/223588356615
# 199      https://blog.naver.com/ok-farm/223598506015
#
#                                            description  \
# 0    장충동 카페 <b>스타벅스</b> 스페셜스토어 장충라운지R점 * 주소 : 서울시 중...
# 1    마롱 헤이즐넛 라떼 <b>스타벅스</b> 신메뉴 <b>스타벅스</b> 신메뉴 소개해...
# 2    오늘은 드디어 <b>스타벅스</b> 버디패스 출시되는 날!! 사실 저는 <b>스타벅...
# 3    <b>스타벅스</b> 플레이모빌 2024 2주차 버디인 킴 빅터 매리 구매 후기입니...
# 4    맞이하여 <b>스타벅스</b>에서도 신메뉴들이 어텀스러운 분위기로 출시되었더라고요....
# ..                                                 ...
# 195  9월 19일 추석이 끝나자마자 지갑 열게 만드는 <b>스타벅스</b>! 헬로키티 캐...
# 196  2024 <b>스타벅스</b> X 플레이모빌 콜라보 9월 27일 오늘부터 <b>스타...
# 197  싱가포르 <b>스타벅스</b> 굿즈 머라이언 쿠키 요즘 싱가포르 두달 살기 하면서 ...
# 198  추석 연휴에는 어떻게 보낼까 하다가 엄마가 네이버 뉴스 기사로 봤다는 용인 고기리 ...
# 199  <b>스타벅스</b> 네스프레소 콜롬비아 싱글 오리진 캡슐커피 &gt;&gt; 상품...
#
#                      bloggername                 bloggerlink  postdate
# 0                            개 집       blog.naver.com/luvzi-  20241002
# 1                    다크윤의 맛집이야기♥   blog.naver.com/darkyoon85  20241001
# 2                ˚✧₊❁⁎솨의봄날⁎⁺˳❁✧༚      blog.naver.com/sohwa91  20241001
# 3                 한가한 오후는 녹차와 함께     blog.naver.com/kastro83  20241007
# 4                      쯘이의 꽃같은일상    blog.naver.com/lovableje  20240927
# ..                           ...                         ...       ...
# 195  ▒ 희나네집 ▒ 라이프스타일디자이너! : 비주언니    blog.naver.com/heena_mom  20240919
# 196  ▒ 희나네집 ▒ 라이프스타일디자이너! : 비주언니    blog.naver.com/heena_mom  20240927
# 197              ♥소소한 박순둥 일상과 여행  blog.naver.com/lovely_sine  20240919
# 198                     쑤토링 테이스트      blog.naver.com/missto5  20240919
# 199                  나른나른 일상 이야기      blog.naver.com/ok-farm  20240927
#
# [200 rows x 6 columns]
