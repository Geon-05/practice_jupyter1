# %%
pwd
# Out:
# 'C:\\Users\\go121\\practice_jupyter\\py\\데이터분석 및 시각화\\API자료수집\\05네이버API'

# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pandas as pd
import json

# 1. id, pw 지정
client_id = "sINqNPstJrYv4dDyStMK"
client_secret = "SKpquTbQWh"

# 2. url 생성
base_url = 'https://openapi.naver.com/v1/search/blog'
p = {
    'query':'abc',
    'display':100,
    'start':1
}
enc_params = urllib.parse.urlencode(p)
url = f'{base_url}?{enc_params}'

# 3. url자료 요청 (json)
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Mon, 07 Oct 2024 10:46:24 +0900",
# 	"total":990482,
# 	"start":1,
# 	"display":100,
# 	"items":[
# 		{
# 			"title":"아산 세차장 꼼꼼한 손세차 <b>ABC<\/b>스팀 GOOD!",
# 			"link":"https:\/\/blog.naver.com\/muumuu77\/223579742017",
# 			"description":"아산 세차장 중 고온 스팀으로 손세차를 해주는 곳을 찾다가 <b>ABC<\/b> 스팀세차를 방문하게되었어요. <b>ABC<\/b>스팀세차 아산점 . 아산시 충무로 90 1층 . 영업시간 09:00 ~ 18:00 휴게시간 13:00 ~ 14:00 . 매주 일요일 휴무... ",
# 			"bloggername":"그녀의 봄날",
# 			"bloggerlink":"blog.naver.com\/muumuu77",
# 			"postdate":"20240910"
# 		},
# 		{
# 			"title":"구리갈매 손세차 추천 - <b>ABC<\/b> 스팀세차장에서 프리미엄 코스로... ",
# 			"link":"https:\/\/blog.naver.com\/firenrain\/223608047484",
# 			"description":"구리갈매 손세차 추천 - <b>ABC<\/b> 스팀세차장 구리갈매에 아는 동생을 만나러 간 김에 세차를 좀 하고 왔다.... <b>ABC<\/b>스팀세차장 구리갈매점은 친절하고 실력도 좋은 사장님이 직접 코스를 진행해주셔서 너무 만족스러운... ",
# 			"bloggername":"시간을 박제하는 공간",
# 			"bloggerlink":"blog.naver.com\/firenrain",
# 			"postdate":"20241005"
# 		},
# 		{
# 			"title":"구리 세차장 <b>ABC<\/b>스팀세차장 구리갈매점 꼼꼼 손세차 후기",
# 			"link":"https:\/\/blog.naver.com\/dmswl0930\/223579757844",
# 			"description":"세차장 <b>ABC<\/b>스팀세차장 구리갈매점을 알게 됐습니다. 타업체 대비 가격도 저렴하고 한 차당 1리터의... <b>ABC<\/b>스팀세차장 구리갈매점 주소 : 경기 구리시 갈매순환로204번길 8-9 1층(갈매동 530-2) 전화번호 : 0507-1386-5032... ",
# 			"bloggername":"햅삐 찌가리",
# 			"bloggerlink":"blog.naver.com\/dmswl0930",
# 			"postdate":"20240911"
# 		},
# 		{
# 			"title":"블랜더 추천 <b>ABC<\/b>주스 가볍게 만드는 방법",
# 			"link":"https:\/\/blog.naver.com\/ha7514\/223535066145",
# 			"description":"요즘은, 단백질 셰이크 말고 <b>ABC<\/b>주스라는 걸 하루에 한 잔씩 마셔주고 있어요. 처음에는 <b>ABC<\/b>주스가 뭐지? 했었는데, 이게 요즘 유행하는 다이어트 주스로 많이들 각광받고 있다고 말을 하더라고요?? 신기했어요.... ",
# 			"bloggername":"활기찬 삶을 위하여 조금씩 노력해가렵니다! 아자아자",
# 			"bloggerlink":"blog.naver.com\/ha7514",
# 			"postdate":"20240805"
# 		},
# 		{
# 			"title":"초고속 블렌더 간단하게 <b>abc<\/b>주스 만들기 엄청 좋아요",
# 			"link":"https:\/\/blog.naver.com\/moondragon-\/223554499984",
# 			"description":"간단하게 <b>abc<\/b>주스 만들기 엄청 좋아요 나이를 먹으니까 자연스럽게 체중이 증가하게 되더라고요 몸무게 위에 올라가니 나오는 숫자들이 너무 충격적이어서 놀랐어요. 그래서 친구의 추천으로 <b>abc<\/b>주스 만들기를... ",
# 			"bloggername":"여름엔 맥주",
# 			"bloggerlink":"blog.naver.com\/moondragon-",
# 			"postdate":"20240821"
# 		},
# 		{
# 			"title":"<b>abc<\/b>쥬스 만들기 <b>abc<\/b>주스 효능 해독주스 만들기",
# 			"link":"https:\/\/blog.naver.com\/lalacucina\/223588456803",
# 			"description":"<b>abc<\/b>쥬스 만들기 해독주스 <b>abc<\/b>주스 효능 해독주스만들기 명절에 기름진 음식을 많이 먹었더니 다이어트를 위한 식단 관리를 잘 해보려고 하는데요 뱃살도 빼고 건강을 위해 몸의 컨디션을 정상으로 회복하고자... ",
# 			"bloggername":"레지나의 라라~쿠치나",
# 			"bloggerlink":"blog.naver.com\/lalacucina",
# 			"postdate":"20240919"
# 		},
# 		{
# 			"title":"부산스팀세차장 동래세차장 <b>ABC<\/b>스팀세차수안점",
# 			"link":"https:\/\/blog.naver.com\/duswk2757\/223609364258",
# 			"description":"전에도 <b>ABC<\/b>스팀세차장을 이용해보았는데 너무 좋았거든요 부산 동래구 온천천로 319 1층 동해동래역 2번 출구에서 606m 찾아가는길 안녕하세요, <b>ABC<\/b>스팀세차장 수안점입니다. 동래경찰서 ,지하철 4호선 수안역... ",
# 			"bloggername":"별빛",
# 			"bloggerlink":"blog.naver.com\/duswk2757",
# 			"postdate":"20241006"
# 		},
# 		{
# 			"title":"중고카메라 매입, 판매 <b>ABC<\/b>카메라를 찾는 이유",
# 			"link":"https:\/\/blog.naver.com\/soary81\/223587425670",
# 			"description":"그래서 오늘은 집에서 상당한 거리임에도 불구하고 새 바디, 렌즈가 필요할 때면 늘 찾게 되는 중고카메라 매입, 판매 전문 업체인 <b>ABC<\/b>카메라의 방문 후기를 남겨볼까 합니다. 먼저 <b>ABC<\/b>카메라는 강변 테크노마트... ",
# 			"bloggername":"소라윙즈의 소소한 IT\/게임 리뷰",
# 			"bloggerlink":"blog.naver.com\/soary81",
# 			"postdate":"20240918"
# 		},
# 		{
# 			"title":"괌 <b>ABC<\/b> 스토어 마트 쇼핑리스트 기념품 추천",
# 			"link":"https:\/\/blog.naver.com\/babastu\/223525476265",
# 			"description":"괌 여행을 가면 한번 이상은 들리게 된다는 괌 <b>ABC<\/b> 스토어 마트 쇼핑리스트 기념품 추천해봅니다 <b>ABC<\/b> 스토어 저는 괌 프리미어 아울렛 안에 있는 <b>ABC<\/b> Stores 510 지점과 투몬 더플라자에 있는 506지점을... ",
# 			"bloggername":"횸니의 소소한 여행로그",
# 			"bloggerlink":"blog.naver.com\/babastu",
# 			"postdate":"20240725"
# 		},
# 		{
# 			"title":"부산스팀세차 <b>ABC<\/b>스팀세차 온천장점 프리미엄코스로 더... ",
# 			"link":"https:\/\/blog.naver.com\/diamond407\/223608707494",
# 			"description":"오늘은 부산 손세차, 스팀세차를 추천해드리려해요 #부산손세차 #부산세차 #부산스팀세차 #<b>ABC<\/b>스팀세차 #<b>ABC<\/b>스팀세차온정장점 #티볼리세차 #내부세차 <b>ABC<\/b>스팀세차의 장점은 체인점이라 가까운 동네에서 만나기... ",
# 			"bloggername":"소담이의 사계절 여행 기록장",
# 			"bloggerlink":"blog.naver.com\/diamond407",
# 			"postdate":"20241006"
# 		},
# 		{
# 			"title":"미국 쇼핑리스트 라스베가스 엠앤엠 월드 (m&amp;m) <b>ABC<\/b>스토어... ",
# 			"link":"https:\/\/blog.naver.com\/danzzak78\/223604903795",
# 			"description":"<b>ABC<\/b> 스토어 숙소에 들어가기 전 <b>ABC<\/b>스토어는 수시로 방문했습니다. 음료와 간단한 간식을 챙기기 위해서였는데 비상약을 구입하기도 좋았습니다. 가장 보편적인 타이레놀도 있고 감기나 몸살 회복에 도움을 주는... ",
# 			"bloggername":"절대미남자와 평생공주의 여행습관",
# 			"bloggerlink":"blog.naver.com\/danzzak78",
# 			"postdate":"20241002"
# 		},
# 		{
# 			"title":"&quot; 부산 세차장 &quot; 잘하는곳 - 연지동 믿고 가는 <b>ABC<\/b> 부산스팀세차... ",
# 			"link":"https:\/\/blog.naver.com\/hadongkwon\/223593167585",
# 			"description":"<b>ABC<\/b> 부산스팀세차 연지본점 부산 진구 연지동 위치랑 운영 시간 등 확인하시구욥. 한적한 동네 골목에 있어 그쪽 동네 잘 모르심 네비는 필수임다~ 부산 세차장 하면 단연 <b>ABC<\/b> 스팀세차 이쥬 ㅋㅋ 부산에 꽤 많은... ",
# 			"bloggername":"동동군의 Multiadapter",
# 			"bloggerlink":"blog.naver.com\/hadongkwon",
# 			"postdate":"20240923"
# 		},
# 		{
# 			"title":"<b>ABC<\/b>주스 만들기 PN진공블렌더 초고속 진공블렌더",
# 			"link":"https:\/\/blog.naver.com\/hyleeyan\/223588458899",
# 			"description":"그래서 건강을 생각해서 요즘 한창 인기템인 <b>ABC<\/b>주스를 만들어 봤어요. 우리몸의 노폐물과 독성을 빼주는 디톡스 다이어트 주스로 엄청 유명합니다. PN 진공블렌더로 먹기좋게 곱게 갈아낸 <b>ABC<\/b>주스는 사과... ",
# 			"bloggername":"요안나의 행복이팍팍",
# 			"bloggerlink":"blog.naver.com\/hyleeyan",
# 			"postdate":"20240920"
# 		},
# 		{
# 			"title":"금곡동 <b>ABC<\/b> 스팀세차에서 손세차 받은 후기",
# 			"link":"https:\/\/blog.naver.com\/extra_yong82\/223583050844",
# 			"description":"유명한 <b>ABC<\/b> 스팀세차 금곡점으로 갔습니다. ▶ 주소 : 부산광역시 북구 금곡대로 460 1층 금곡동 하나로... 효소 톡톡!이라는 <b>abc<\/b> 스팀세차만의 전용 세제가 신기했어요. 믿음이 확~! 가는데요! C코스(내부+외부)... ",
# 			"bloggername":"SOYO LIFE",
# 			"bloggerlink":"blog.naver.com\/extra_yong82",
# 			"postdate":"20240913"
# 		},
# 		{
# 			"title":"사이판 쇼핑리스트 <b>ABC<\/b>스토어 헬로키티 50주년 인형",
# 			"link":"https:\/\/blog.naver.com\/melodytravel\/223586000555",
# 			"description":"사이판에서 기념품을 구매할 수 있는 상점 중 <b>ABC<\/b>스토어가 있습니다. <b>ABC<\/b> Stores 여기서는 헬로키티 50주년 기념으로 나온 태닝을 한 인형을 구매할 수 있답니다. <b>ABC<\/b> Stores 가라판점 주소 : 6P69+524, Garapan, Saipan... ",
# 			"bloggername":"멜로디의 꼼꼼한 여행",
# 			"bloggerlink":"blog.naver.com\/melodytravel",
# 			"postdate":"20240916"
# 		},
# 		{
# 			"title":"부산 금곡동 세차장 추천  <b>ABC<\/b>스팀세차장 금곡점",
# 			"link":"https:\/\/blog.naver.com\/dannnyyy\/223584351699",
# 			"description":"이 모든 게 세차에 사용하는 세재들~ <b>ABC<\/b>스팀세차는 화학약품을 사용하지 않고 오직 친환경세재만을 이용해서 세차를 합니다. 이게 <b>ABC<\/b>스팀세차 매장들의 강점인거같아요. 바로 이 자체 개발한 효소톡톡이라는... ",
# 			"bloggername":"시간의 기록",
# 			"bloggerlink":"blog.naver.com\/dannnyyy",
# 			"postdate":"20240914"
# 		},
# 		{
# 			"title":"<b>ABC<\/b>스팀세차장 수안점",
# 			"link":"https:\/\/blog.naver.com\/82love7942v\/223581359916",
# 			"description":"<b>ABC<\/b>스팀세차장 수안점 위치는 동래구 온천천로 319 1층입니다. 영업시간 및 전화번호 시간 : 9:00~ 18:00 (13... 세차장에 담배 냄새나 각종 냄새가 많이 나는곳도 많은데 동래세차장인 <b>ABC<\/b>스팀세차장 수안점은 실내도... ",
# 			"bloggername":"육아가 서툰 엄마의 육아",
# 			"bloggerlink":"blog.naver.com\/82love7942v",
# 			"postdate":"20240912"
# 		},
# 		{
# 			"title":"해운대세차장 추천 | <b>abc<\/b>스팀세차장 센텀점",
# 			"link":"https:\/\/blog.naver.com\/laphroaig_\/223583369009",
# 			"description":"<b>abc<\/b>스팀세차장 센텀점입니닷 <b>abc<\/b>스팀세차장 센텀점 영업시간 : 월\/목 : 10:00-19:00 ( 정기휴무 : 매주 일요일 ) 전화번호 : 0507-1436-9411 세차 가격 코스별로 다양하게 정가로 가격을 제시해주셔서 직관적으로 보기... ",
# 			"bloggername":"긴긴밤",
# 			"bloggerlink":"blog.naver.com\/laphroaig_",
# 			"postdate":"20240913"
# 		},
# 		{
# 			"title":"구리세차장  <b>ABC<\/b> 스팀세차장에서 카시트까지 손세차완료!",
# 			"link":"https:\/\/blog.naver.com\/ama-gonggan\/223579693534",
# 			"description":"오늘은 합리적인 가격과 더불어 깔끔한 시설과 다양한 장비들을 보유한 구리세차장인 <b>ABC<\/b> 스팀세차장을 방문하게 되었다. 구리세차장 \/ 구리손세차 \/ 구리스팀세차 <b>ABC<\/b> 스팀세차장 구리 갈매점 @글, 사진... ",
# 			"bloggername":"아마의공간 ⌂",
# 			"bloggerlink":"blog.naver.com\/ama-gonggan",
# 			"postdate":"20240910"
# 		},
# 		{
# 			"title":"사이판 태닝키티 한정판 산리오 기념품 가라판 쇼핑몰 <b>ABC<\/b>마... ",
# 			"link":"https:\/\/blog.naver.com\/mkk1830\/223589905177",
# 			"description":"사이판 가라판 <b>ABC<\/b>마트 기념품 쇼핑몰 태닝키티 가격 산리오 캐릭터 사이판 여행을 하면서 하루의... ■ 월요일 ~ 일요일 OPEN 08:00 - CLOSE 22:00 가라판 <b>ABC<\/b>마트 태닝키티 가격 가라판 <b>ABC<\/b>마트는 오전부터 영업을... ",
# 			"bloggername":"여기저기 숑숑여행 : 솜숑미",
# 			"bloggerlink":"blog.naver.com\/mkk1830",
# 			"postdate":"20240922"
# 		},
# 		{
# 			"title":"<b>ABC<\/b>주스 디톡스주스 다이어트 클렌즈 해독주스 라티브 선택",
# 			"link":"https:\/\/blog.naver.com\/hitomi1228\/223595223191",
# 			"description":"무거워진 몸을 다시 가볍게 만들어주기 위해 아침에 <b>ABC<\/b>주스를 챙겨 마시기로 했어요. 홈메이드... 그래서 이번에 꾸준하게 챙겨 마시기 위해 해독주스 주문을 알아보다가 라티브 <b>ABC<\/b>주스를 선택했어요.... ",
# 			"bloggername":"스위트카렌의 달달한 작업실",
# 			"bloggerlink":"blog.naver.com\/hitomi1228",
# 			"postdate":"20240924"
# 		},
# 		{
# 			"title":"<b>ABC<\/b>스팀세차 천안점 다녀왔습니다",
# 			"link":"https:\/\/blog.naver.com\/rkdudwhdk\/223573534932",
# 			"description":"청당동에 위치한 <b>ABC<\/b>스팀세차 천안점인데요, 타 업체 대비 저렴한 스팀세차 가격으로 유명한 곳입니다.... <b>ABC<\/b>스팀세차장은 따로 대기실이 준비되어 있지 않습니다. 하지만 옆건물에 보시면 투썸플레이스 카페가... ",
# 			"bloggername":"WONDERFUL02",
# 			"bloggerlink":"blog.naver.com\/rkdudwhdk",
# 			"postdate":"20240905"
# 		},
# 		{
# 			"title":"국내산 통째로 갈아만든 건강 황금이네 <b>ABC<\/b> 쥬스 효능",
# 			"link":"https:\/\/blog.naver.com\/chuing_____\/223606570082",
# 			"description":"국내산 통째로 갈아만든 건강 황금이네 <b>ABC<\/b> 쥬스 효능 <b>ABC<\/b> 주스 많이 들어보셨죠? 사과(Apple), 비트(Beet), 당근(Carrot) 을 갈아 넣은 주스로, 혈관을 청소해 주고 장과 간을 해독하는 효과가 있습니다. (*원료적... ",
# 			"bloggername":"허밍레시피 ♬",
# 			"bloggerlink":"blog.naver.com\/chuing_____",
# 			"postdate":"20241004"
# 		},
# 		{
# 			"title":"아산 친환경 <b>ABC<\/b> 스팀세차",
# 			"link":"https:\/\/blog.naver.com\/chloeyim86\/223572261039",
# 			"description":"<b>ABC<\/b>스팀세차 아산점 월~토 09:00 - 18:00 드디어 두달만에 세차했습니다! 아이 학원 라이딩 하느라 항상... 있는 <b>ABC<\/b>스팀세차 입니다. 대로변에 있어서 찾기 힘들지 않아요 예약하고 도착하면 사장님께서 엄청 반갑게... ",
# 			"bloggername":"우니의 개인생활",
# 			"bloggerlink":"blog.naver.com\/chloeyim86",
# 			"postdate":"20240904"
# 		},
# 		{
# 			"title":"대구 약령시 프라이빗 카페 <b>ABC<\/b> 라운지",
# 			"link":"https:\/\/blog.naver.com\/simplehi-\/223607240519",
# 			"description":"친구가 추천해 준 카페 <b>ABC<\/b> 라운지, 사실 카페로 추천했다기보다는 책을 추천해 준 거였는데 막상 가서 보니 꽤 괜찮은 프라이빗 한 북 카페였다. Art, Book, Coffee의 앞 머릿 자만 따온 <b>ABC<\/b> 라운지 프라이빗하게... ",
# 			"bloggername":"심플하이",
# 			"bloggerlink":"blog.naver.com\/simplehi-",
# 			"postdate":"20241004"
# 		},
# 		{
# 			"title":"휴롬착즙기 H410 사용후기 <b>ABC<\/b>주스 만들기",
# 			"link":"https:\/\/blog.naver.com\/kangsncs\/223330933359",
# 			"description":"그 중에서 가장 제 입맛에 맞는 <b>ABC<\/b>주스도 같이 소개해볼까해요. 휴롬 H410착즙기 전 처음 꺼내보고는... <b>ABC<\/b>주스 만들기 제가 주로 짜먹는 주스는 바로 <b>ABC<\/b>주스에요. Apple(사과) Beet(비트) Carrot(당근)의 약자를 따서... ",
# 			"bloggername":"워킹맘의 저녁육아",
# 			"bloggerlink":"blog.naver.com\/kangsncs",
# 			"postdate":"20240123"
# 		},
# 		{
# 			"title":"괌 쇼핑 T갤러리아 스투시 <b>ABC<\/b> 스토어 가격",
# 			"link":"https:\/\/blog.naver.com\/coolestlove\/223591801776",
# 			"description":"괌 쇼핑 T갤러리아 스투시 <b>ABC<\/b> 스토어 가격 러블리썬 X GUAM 안녕하세요 여행블로거 #러블리썬 입니다.... 좋겠어요 <b>ABC<\/b>스토어 괌쇼핑 괌 기념품과 여러 가지 구입할 수 있는 곳이에요 사이판에서도 보이는... ",
# 			"bloggername":"❤️러블리썬✈️여행하기 좋은 날",
# 			"bloggerlink":"blog.naver.com\/coolestlove",
# 			"postdate":"20240922"
# 		},
# 		{
# 			"title":"괌 렌트카, <b>ABC<\/b> 렌트카 면허정보 예약방법 이용후기 공유",
# 			"link":"https:\/\/blog.naver.com\/phm8739\/223573326557",
# 			"description":"바로 ‘괌 <b>ABC<\/b> 렌트카’ 업체인데요. 한국인 직원이 없는 현지 렌트카 업체이지만 한국인 직원들께서... 괌렌트카예약 _ ‘괌 <b>ABC<\/b> 렌트카’ 혜택 안내 위에서 간단히 안내 드렸던 대로, 괌 <b>ABC<\/b> 렌트카 업체는 현지... ",
# 			"bloggername":"여행가자고",
# 			"bloggerlink":"blog.naver.com\/phm8739",
# 			"postdate":"20240905"
# 		},
# 		{
# 			"title":"쿠키만들기(No슈가파우더,제티+<b>ABC<\/b>초콜릿 콜라보.",
# 			"link":"https:\/\/blog.naver.com\/jiddumiss\/223600092811",
# 			"description":"70g <b>ABC<\/b>초콜릿 (취향에 따라 알아서 \/ 초코쿠키용 초코칩을 사도 무방) 제티 1포 (생략가능) 계란도 버터도... 만들어본다 :) <b>ABC<\/b>초콜릿도 칼로 부숴서 위에 올렸는데 쿠키용 초코칩이 아니라 잘 되려나 걱정했지만... ",
# 			"bloggername":"부산댁, 육아일상",
# 			"bloggerlink":"blog.naver.com\/jiddumiss",
# 			"postdate":"20240929"
# 		},
# 		{
# 			"title":"복부 비만, 내장지방 비만을 위한 레시피 <b>ABC<\/b> 주스",
# 			"link":"https:\/\/blog.naver.com\/miin1869\/223604634899",
# 			"description":"알지만 운동 등 실천을 못하고 계시는 분들을 위한 레시피 <b>ABC<\/b> 주스 바쁜 출근시간, 운동을 할 시간이 없는 분들이라면 <b>ABC<\/b> 주스로 관리해 보시는 것을 권해드립니다 건강관리 첫 번째는 스트레스를 받지 않는... ",
# 			"bloggername":"약초본가",
# 			"bloggerlink":"blog.naver.com\/miin1869",
# 			"postdate":"20241002"
# 		},
# 		{
# 			"title":"괌 <b>ABC<\/b> 스토어 쇼핑리스트 기념품 추천 영업시간",
# 			"link":"https:\/\/blog.naver.com\/dorothy_1114\/223559443322",
# 			"description":"괌 <b>ABC<\/b> 스토어 괌 쇼핑리스트 기념품 추천 영업시간 태교여행으로 다녀온 괌 괌 여행 가면 쇼핑도... 괌 <b>ABC<\/b> 스토어 다녀왔어용 괌 여행 일정 1일차에 마침 근처에 있어서 둘러볼 겸 가봤어용 괌 <b>ABC<\/b>스토어... ",
# 			"bloggername":"취미부자 뽀도미",
# 			"bloggerlink":"blog.naver.com\/dorothy_1114",
# 			"postdate":"20240824"
# 		},
# 		{
# 			"title":"<b>ABC<\/b> 주스 레시피 디톡스주스",
# 			"link":"https:\/\/blog.naver.com\/dasomammy\/223574559050",
# 			"description":"작년 6개월간 꾸준히 아침으로 마신 <b>abc<\/b>주스. 고지혈증에 당뇨전단계, 고혈압 전단계 판정 받고 식단을 바꾸려고 시작한 계기죠. 아침에 일어나 따뜻한 물 한잔 마시고 잠시 후 <b>abc<\/b>주스 한잔 마시고... ",
# 			"bloggername":"다소마미의 오늘요리",
# 			"bloggerlink":"blog.naver.com\/dasomammy",
# 			"postdate":"20240907"
# 		},
# 		{
# 			"title":"누팬트리 <b>ABC<\/b> 주스 비율 및 공복 섭취법 실사용 후기",
# 			"link":"https:\/\/blog.naver.com\/qhwn0130\/223573375928",
# 			"description":"누팬트리 <b>ABC<\/b> 주스  요즘 건강을 챙기기 위해 다들 한 번쯤 들어봤을 <b>ABC<\/b> 주스. 사과, 비트, 당근으로 만드는 주스는 몸에 좋은 성분으로 가득 차 있어서 디톡스, 체중 감량, 피부 개선 등 다양한 효과가 있다고... ",
# 			"bloggername":"라임보돌 감성 더하기",
# 			"bloggerlink":"blog.naver.com\/qhwn0130",
# 			"postdate":"20240905"
# 		},
# 		{
# 			"title":"HAFA ADAI :)  괌 DAY6 - K마트 환불, 끌로에 우디백, <b>ABC<\/b>스토... ",
# 			"link":"https:\/\/blog.naver.com\/pumac02\/223599881031",
# 			"description":"첫 날 받았던 사은품 안내 카드- <b>ABC<\/b>스토어 촘촘따리 영수증 다 합쳐서 사은품 받으려고 방문함! 100달러... JP스토어 + <b>ABC<\/b>마트 구매샷 받고 끌로에+ 슈프림 + 면세템 + T갤러리아 구매템 괌 특이점이 오는 귀여운... ",
# 			"bloggername":"잡다한 바스켓",
# 			"bloggerlink":"blog.naver.com\/pumac02",
# 			"postdate":"20240928"
# 		},
# 		{
# 			"title":"부산 스팀세차 <b>ABC<\/b>스팀세차장 하단점",
# 			"link":"https:\/\/blog.naver.com\/daisykim1987\/223581468603",
# 			"description":"사하구 세차장 중에 스팀하는 곳을 찾다 하단 세차장 <b>ABC<\/b>스팀 세차장 하단점을 방문하게 되었네요. 이 날... 서비스정신이 남다른 하단세차장 <b>ABC<\/b> 스팀세차장 하단점 비포사진이 한눈에 보아도 진짜 더럽다는게... ",
# 			"bloggername":"잘사는엄마 ABO LIFE",
# 			"bloggerlink":"blog.naver.com\/daisykim1987",
# 			"postdate":"20240912"
# 		},
# 		{
# 			"title":"국내산 통째로 갈아만든 황금이네 <b>ABC<\/b> 쥬스",
# 			"link":"https:\/\/blog.naver.com\/chuing_____\/223552041838",
# 			"description":"국내산 통째로 갈아만든 황금이네 <b>ABC<\/b> 쥬스 평소 <b>ABC<\/b>주스를 해먹으려고 사과, 당근, 비트를 샀다가 시들시들해져서 그냥 버리기 일쑤라 국내산으로 만든 황금이네 <b>ABC<\/b>주스를 먹어보게 됐어요. 따로 과일과... ",
# 			"bloggername":"허밍레시피 ♬",
# 			"bloggerlink":"blog.naver.com\/chuing_____",
# 			"postdate":"20240818"
# 		},
# 		{
# 			"title":"NFC착즙주스 건강한 과채주스 팁코 <b>ABC<\/b>쥬스 효능",
# 			"link":"https:\/\/blog.naver.com\/renapark99\/223547075960",
# 			"description":"<b>ABC<\/b>쥬스 효능 평소 건강에 관심도 많은 편이라 건강즙을 다양하게 시도해 보는데요. 부지런하지 못해서 직접 만들어 먹는 건 매번 실패했어요. CCA주스도 도전해 봤지만 저는 사과 비트 당근이 들어간 <b>ABC<\/b>쥬... ",
# 			"bloggername":"하루레나의 Slow life",
# 			"bloggerlink":"blog.naver.com\/renapark99",
# 			"postdate":"20240813"
# 		},
# 		{
# 			"title":"살기 中 SMEAG 딸락 7주] 현지 로컬마트 장보기 (<b>ABC<\/b>마트)",
# 			"link":"https:\/\/blog.naver.com\/namme46\/223595806448",
# 			"description":"SMEAG딸락캠퍼스에서 트라이시클을 타면 100페소(약2,500원)만 내도 <b>ABC<\/b>마트에 갈 수 있어요 왕복으로 트라이시클이 부담스러우시다면 매일 시내로 셔틀버스를 타고 중간에내려 <b>ABC<\/b>마트에 가서 장을 보고... ",
# 			"bloggername":"봉군엄마♡(봉준쭌일상)",
# 			"bloggerlink":"blog.naver.com\/namme46",
# 			"postdate":"20240925"
# 		},
# 		{
# 			"title":"무아, 넌 어떤요정이니_시흥 <b>ABC<\/b> 행복 학습타운_동화 오페라",
# 			"link":"https:\/\/blog.naver.com\/moongbaby\/223600949633",
# 			"description":"시흥시 <b>ABC<\/b>행복 학습타운 홀에서 열린 무아, 넌 어떤 요정이니? 어린이 판타지 동화 오페라를 보고... 시흥 <b>ABC<\/b>학습타운 홀은 단층으로 단차가 크지는 않지만 대부분의 자리의 시야가 괜찮아 보였어요. 주인공... ",
# 			"bloggername":"Daily",
# 			"bloggerlink":"blog.naver.com\/moongbaby",
# 			"postdate":"20240929"
# 		},
# 		{
# 			"title":"라라포트 쇼핑 후기(ft. 아카짱혼포, 유니클로, <b>ABC<\/b>마트)",
# 			"link":"https:\/\/blog.naver.com\/thehaven7\/223598901242",
# 			"description":"아카짱혼포, 유니클로, <b>ABC<\/b>마트) 이번에 이야기할 내용은 후쿠오카 라라포트 쇼핑 후기(ft. 아카짱혼포, 유니클로, <b>ABC<\/b>마트)다. 하카타역에서 라라포트 가는 법 : 네이버 블로그 (naver.com) 하카타에서 라라포트... ",
# 			"bloggername":"옆집행님",
# 			"bloggerlink":"blog.naver.com\/thehaven7",
# 			"postdate":"20240928"
# 		},
# 		{
# 			"title":"<b>ABC<\/b> 뉴스의 대선 토론 조작을 폭로한 내부고발자",
# 			"link":"https:\/\/blog.naver.com\/onlythelife\/223592896533",
# 			"description":"공정성 논란이 벌어진 <b>ABC<\/b>의 대선 토론에 대한 내부고발이 나왔다. <b>ABC<\/b> 뉴스가 카멀라 해리스에게 유리하도록 지난 10일의 대선 토론을 사전에 조작했다는 내부자의 고발이 나왔다. 고발 내용을 요약하면... ",
# 			"bloggername":"\"♡하 · 늘 · 생 · 명♡\"",
# 			"bloggerlink":"blog.naver.com\/onlythelife",
# 			"postdate":"20240923"
# 		},
# 		{
# 			"title":"아침대용 공복에 마시는 누팬트리 <b>ABC<\/b> 주스",
# 			"link":"https:\/\/blog.naver.com\/jungwun113\/223573232934",
# 			"description":"아침대용 공복에 마시는 누팬트리 <b>ABC<\/b> 주스 하루 먹는 식단에서 과일 야채 섭취량이 현저하게 낮다 보니 균등한 영양소 섭취 습관을 길들이기 위해 <b>ABC<\/b> 쥬스를 마시기 시작했어요. 아침은 입맛이 없다 보니... ",
# 			"bloggername":"하얀솜구름의 구름공방",
# 			"bloggerlink":"blog.naver.com\/jungwun113",
# 			"postdate":"20240905"
# 		},
# 		{
# 			"title":"<b>ABC<\/b>주스 클렌즈주스 김의준고구마 베스트 추천",
# 			"link":"https:\/\/blog.naver.com\/nijal99\/223557362045",
# 			"description":"요즘 매일 아침 저녁 두번 챙겨먹는 건강주스 <b>ABC<\/b>주스 알록달록 포장 패키지부터 하루를 시작하는 아침 기분좋게 해주는데요. 건강해서 좋고, 맛있기까지한~ 클렌즈주스로 챙겨도 좋을 <b>ABC<\/b>주스 소개해볼게요.... ",
# 			"bloggername":"골프쟁이 뷰티 패션 이야기",
# 			"bloggerlink":"blog.naver.com\/nijal99",
# 			"postdate":"20240823"
# 		},
# 		{
# 			"title":"국내산 원물 <b>ABC<\/b> 쥬스 통째로 갈아넣어 건강한 황금이네... ",
# 			"link":"https:\/\/blog.naver.com\/alfojw\/223569739211",
# 			"description":"국내산 원물 <b>ABC<\/b> 쥬스 통째로 갈아넣어 건강한 황금이네 과채주스 저희는 요즘 아이들은 물론 저와 신랑도 함께 <b>ABC<\/b> 쥬스를 챙겨먹고 있는데요. 물 한방울 넣지 않고 국내산 사과, 당근, 레드비트를 원물... ",
# 			"bloggername":"두봄자매의 전원라이프",
# 			"bloggerlink":"blog.naver.com\/alfojw",
# 			"postdate":"20240902"
# 		},
# 		{
# 			"title":"팁코 <b>ABC<\/b>주스 사과당근비트 아이가 잘 먹는 과채 주스",
# 			"link":"https:\/\/blog.naver.com\/elaine333\/223481418689",
# 			"description":"팁코 <b>ABC<\/b>주스 사과당근비트 아이가 잘 먹는 과채 주스 글. 사진 \/ 이주경 안녕하세요. 진심이 통하는... 아이가 잘먹는 팁코, 이번에는 팁코 <b>ABC<\/b>를 준비 했답니다. 아이만 먹을게 아니라 저도 같이 먹으려고 <b>ABC<\/b>... ",
# 			"bloggername":"진심이 통하는 시간 ,",
# 			"bloggerlink":"blog.naver.com\/elaine333",
# 			"postdate":"20240616"
# 		},
# 		{
# 			"title":"저속노화쌤 정희원 교수 추천 #저속노화 소이주스 #<b>ABC<\/b>두유",
# 			"link":"https:\/\/blog.naver.com\/huromblog\/223579284786",
# 			"description":"레시피, <b>ABC<\/b>두유 레시피를 소개해드릴게요! *첫번째 저속노화소이주스 레시피, CCA두유가 궁금하신분은 여기!  [H410] 저속노화쌤 정희원 교수의 추천, #저속노화 소이주스 #<b>ABC<\/b>두유 레시피 먼저 오늘의... ",
# 			"bloggername":"자연을 그대로 만나는 방법, 휴롬",
# 			"bloggerlink":"blog.naver.com\/huromblog",
# 			"postdate":"20240910"
# 		},
# 		{
# 			"title":"써코니 엔돌핀 스피드 4, 수원스타필드 <b>ABC<\/b>마트... ",
# 			"link":"https:\/\/blog.naver.com\/m0rae\/223603133855",
# 			"description":"<b>ABC<\/b>마트가 써코니 공식판매처고, 써코니의 러닝화는 <b>ABC<\/b>마트 그랜드스테이지에서만 구매할 수 있다. 일반 <b>ABC<\/b>마트에선 안 판다고 함. 그래서 그랜드스테이지가 입점돼있는 수원스타필드에 갔다. 신세계 상품권도... ",
# 			"bloggername":"모래스냅, 단편사진관",
# 			"bloggerlink":"blog.naver.com\/m0rae",
# 			"postdate":"20241001"
# 		},
# 		{
# 			"title":"앙헬라스 <b>ABC<\/b> HOTEL 이용후기",
# 			"link":"https:\/\/blog.naver.com\/wkyang65\/223559047104",
# 			"description":"앙헬라스 <b>ABC<\/b> HOTEL 을 숙소로 이용 하엿던 이야기 입니다. 아고다을 통하여서 5박6일 을 AQUA SUITE 을... <b>ABC<\/b> HOTEL 의 유명한 사진 픽 장소 이곳의 인테리어는 유럽 피안 스타일 과 미국 스타일이 섞여 놓은 듯... ",
# 			"bloggername":"라이팅맨 님의 블로그",
# 			"bloggerlink":"blog.naver.com\/wkyang65",
# 			"postdate":"20240824"
# 		},
# 		{
# 			"title":"클렌즈주스 추천 김의준고구마 통째로 갈아만든 진짜 <b>ABC<\/b>주스",
# 			"link":"https:\/\/blog.naver.com\/cooloo9149\/223579024680",
# 			"description":"요즘 건강관리를 위해 매일 아침마다 <b>ABC<\/b>주스를 마시고 있는데요. 직접 만들어 먹는 게 번거롭기도 하고... 국내산 재료만 사용한 클렌즈주스 추천 김의준고구마 통째로 갈아만든 진짜 <b>ABC<\/b>주스는 오직 국내산... ",
# 			"bloggername":"도니콘과 다이어터 :)",
# 			"bloggerlink":"blog.naver.com\/cooloo9149",
# 			"postdate":"20240910"
# 		},
# 		{
# 			"title":"운중초영어학원] <b>ABC<\/b>반 (알파벳기초반)",
# 			"link":"https:\/\/blog.naver.com\/mvenglish\/223609588390",
# 			"description":"판교운중초영어학원] <b>ABC<\/b>반 (알파벳기초반) 판교운중초영어학원 MV영어학원입니다. 파닉스 1반은... 1. <b>ABC<\/b> 알파벳 쓰는법 숙지 - 요즘 학생들이 글씨를 너무 못써서 알아볼수가 없을뿐만 아니라 r이나 n h m... ",
# 			"bloggername":"MV 영어학원 MegaVision 4 English 031-8016-0542",
# 			"bloggerlink":"blog.naver.com\/mvenglish",
# 			"postdate":"20241007"
# 		},
# 		{
# 			"title":"대구 북카페 <b>abc<\/b>라운지 - 기품있는 서비스",
# 			"link":"https:\/\/blog.naver.com\/simple_choi\/223566045897",
# 			"description":"대구, 신비로운 북카페 <b>abc<\/b>라운지에서 말입니다. ▷대구 북카페 <b>abc<\/b>라운지 첫번째 방문 - 조용한 우리만의 공간 겉으로 보였던 1층 분위기와는 다른 이 아늑한 공간은 <b>abc<\/b>카페 2층입니다. 이날 함께 했던... ",
# 			"bloggername":"심플초이",
# 			"bloggerlink":"blog.naver.com\/simple_choi",
# 			"postdate":"20240830"
# 		},
# 		{
# 			"title":"비트코인 <b>ABC<\/b> 하드포크와 그 영향 알아보기",
# 			"link":"https:\/\/blog.naver.com\/dennis08\/223592703086",
# 			"description":"비트코인 <b>ABC<\/b> 하드포크와 그 영향 알아보기 안녕하세요, 데니스입니다! 여러분, 최근에 비트코인 시장에서 꽤 흥미로운 일이 있었는데요. 바로 비트코인 <b>ABC<\/b> 하드포크에 관한 거예요. 새로운 기술이나... ",
# 			"bloggername":"주절주절",
# 			"bloggerlink":"blog.naver.com\/dennis08",
# 			"postdate":"20240923"
# 		},
# 		{
# 			"title":"<b>ABC<\/b> 쥬스 황금이네 <b>abc<\/b>주스 맛있어요 추천",
# 			"link":"https:\/\/blog.naver.com\/haejin329\/223580958276",
# 			"description":"<b>ABC<\/b> 쥬스 황금이네 <b>abc<\/b> 주스 맛있어요 ! 추천 이사오고 집 냉장고가 텅 비어있어서 일단 간단히 먹을 수 있는 걸로 채워야지 하다가 황금이네 <b>ABC<\/b> 쥬스로 채워보았어요 :) 1박스에 30포가 들어있어요 1박스를... ",
# 			"bloggername":"Things I'd love to do",
# 			"bloggerlink":"blog.naver.com\/haejin329",
# 			"postdate":"20240911"
# 		},
# 		{
# 			"title":"팁코, NFC착즙 <b>ABC<\/b>주스 하루 한팩 디톡스케어 tipco",
# 			"link":"https:\/\/blog.naver.com\/3120ann\/223553300853",
# 			"description":"오늘은 제가 요즘 아침마다 일어나자마자 꼭 한팩씩 챙겨 마시고 있는 팁코 NFC착즙 <b>ABC<\/b>주스 후기로... 그럴때 이 팁코 <b>ABC<\/b>주스를 한팩 마셔주면 든든 그자체네요. 아들 여름방학 까지 겹쳐서 아침에 무한 기력... ",
# 			"bloggername":"SEOYISOB",
# 			"bloggerlink":"blog.naver.com\/3120ann",
# 			"postdate":"20240819"
# 		},
# 		{
# 			"title":"황금이네 <b>ABC<\/b> 쥬스 넘 맛있어서 어디든 가져가요",
# 			"link":"https:\/\/blog.naver.com\/tak2chef\/223580865480",
# 			"description":"왜때문에 황금이네 <b>abc<\/b> 주스 는 맛잇게 잘 먹을까요 ? ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 몸에 좋은 사과 ! 당근 ! 비트 ! 를 갈아 간편하고 맛있게 즐길 수 있는 ~~~ <b>ABC<\/b> 쥬스 소개해드릴게오 =333 ＃<b>abc<\/b> 주스... ",
# 			"bloggername":"09nin's 달콤연애♥",
# 			"bloggerlink":"blog.naver.com\/tak2chef",
# 			"postdate":"20240911"
# 		},
# 		{
# 			"title":"<b>ABC<\/b>해독주스 아이들과 함께 건강한 팁코 클렌즈주스 추천",
# 			"link":"https:\/\/blog.naver.com\/yhm529\/223554893374",
# 			"description":"끼니도 불규칙하고, 야식에 맥주에 안건강하게 먹었더니 급격하게 살도 찌고, 몸도 찌뿌둥해지는 것 같아서 건강한 <b>ABC<\/b>해독주스로 아침도 해결하고 몸을 좀 가볍게 하고 싶어서 <b>ABC<\/b>해독주스를 좀 알아보다가... ",
# 			"bloggername":"밍밍 & 슈림프's BLOG",
# 			"bloggerlink":"blog.naver.com\/yhm529",
# 			"postdate":"20240820"
# 		},
# 		{
# 			"title":"<b>abc<\/b>주스 혈당 클렌즈주스 추천 김의준고구마",
# 			"link":"https:\/\/blog.naver.com\/daisy_yam\/223576724168",
# 			"description":"사과, 당근, 비트를 통째로 갈아만드는 <b>abc<\/b>주스! 여전히 핫한 건강 주스이죠. 공복으로 출근하는 남편이 가끔은 미안하기도 하고,, 안쓰럽기도 해서 <b>abc<\/b>주스로 아침 건강 챙겨주고 있어요. ㅎㅎ (미안 ~남편... ",
# 			"bloggername":"꿈꾸던 행복한 일상♡",
# 			"bloggerlink":"blog.naver.com\/daisy_yam",
# 			"postdate":"20240908"
# 		},
# 		{
# 			"title":"<b>ABC<\/b>주스 추천 클렌즈주스 김의준고구마 황금비율",
# 			"link":"https:\/\/blog.naver.com\/topncrystal\/223578952871",
# 			"description":"저는 김의준고구마 <b>ABC<\/b>주스 추천을 마시고 있어요. 통째로 갈아만든 진짜 <b>ABC<\/b>주스 예요. 포장 패키지도 예뻐요. 주변에 선물하기에도 좋은 패키지가 돋보여요. 손으로 휘릭 들고 가기에도 좋더라구요. 그래서... ",
# 			"bloggername":"크리스탈 라이프스타일",
# 			"bloggerlink":"blog.naver.com\/topncrystal",
# 			"postdate":"20240910"
# 		},
# 		{
# 			"title":"<b>ABC<\/b> 쥬스 물 한 방울 넣지 않은 황금이네",
# 			"link":"https:\/\/blog.naver.com\/zxcv7971\/223551921365",
# 			"description":"<b>ABC<\/b> 쥬스를 먹고 있어요 직접 갈아먹으면 좋겠지만 아이들 밥 차리는 것만으로도 벅차서 도저히 만들어 먹을 자신은 없고 아이들과 함께 먹을 거라 아무거나 고를 수도 없고 그래서 저는 황금이네 <b>ABC<\/b>... ",
# 			"bloggername":"Love House님의 블로그",
# 			"bloggerlink":"blog.naver.com\/zxcv7971",
# 			"postdate":"20240818"
# 		},
# 		{
# 			"title":"클렌즈주스 추천 김의준고구마 <b>ABC<\/b>주스",
# 			"link":"https:\/\/blog.naver.com\/ssong920\/223577624923",
# 			"description":"클렌즈주스 추천 김의준고구마 <b>ABC<\/b>주스 운동을 시작하고나니 집에서 마시는 음료수 하나까지... 김의준고구마 통째로 갈아만든 <b>ABC<\/b>주스 클렌즈주스 추천 30포 19,900 수많은 <b>ABC<\/b>주스들이 검색되어 나왔지만... ",
# 			"bloggername":"H A F F Y H A A : L O G",
# 			"bloggerlink":"blog.naver.com\/ssong920",
# 			"postdate":"20240909"
# 		},
# 		{
# 			"title":"리타<b>ABC<\/b>주스 사과당근주스 한팩으로 해결해요.",
# 			"link":"https:\/\/blog.naver.com\/ljs-777\/223566541265",
# 			"description":"몸에 좋다고 하여 <b>abc<\/b>주스를 직접 갈아먹었는데 너무 번거로웠어요. 매번 사과, 비트, 당근, 씻어서... 바로 리타<b>ABC<\/b>주스예요. 그래서 여러분께 리타<b>ABC<\/b>주스에 대해 소개해 드리려고 해요. A(사과)B(비트)C(당근)... ",
# 			"bloggername":"건강고래 리리의 튼튼생활",
# 			"bloggerlink":"blog.naver.com\/ljs-777",
# 			"postdate":"20240830"
# 		},
# 		{
# 			"title":"[<b>ABC<\/b> 쥬스 추천]황금이네 <b>abc<\/b> 주스로 가벼운 아침 시작!",
# 			"link":"https:\/\/blog.naver.com\/5jinhwa\/223591928751",
# 			"description":"<b>ABC<\/b> 쥬스 추천 황금이네 <b>abc<\/b> 주스 직장인 아침 대용 다이어트 주스 요즘 저의 최대 관심사는 건강한 다이어트인데요! 특히 쉽고 간편한 다이어트 방법을 찾는 제가 자연스럽게 관심을 가지게 된 <b>abc<\/b>주스..!!!... ",
# 			"bloggername":"모든 요일의 기록",
# 			"bloggerlink":"blog.naver.com\/5jinhwa",
# 			"postdate":"20240922"
# 		},
# 		{
# 			"title":"클렌즈주스다이어트 <b>abc<\/b>주스 추천 김의준고구마",
# 			"link":"https:\/\/blog.naver.com\/qkenrdl1004\/223578481027",
# 			"description":"원물 그대로만 넣고 착즙해서 만든 순수 즙음료인 <b>abc<\/b>주스 추천을 많이하길래 둘러보니 어떤 첨가물도... 싶었다 그리고 아무런 첨가 없이 채소와 과일만의 착즙인 <b>abc<\/b>주스이기에, 아이도 함께 먹을 수 있어서 더... ",
# 			"bloggername":"엄빠의 일기장",
# 			"bloggerlink":"blog.naver.com\/qkenrdl1004",
# 			"postdate":"20240910"
# 		},
# 		{
# 			"title":"김의준고구마 쇼핑몰 <b>ABC<\/b>주스 혈당 관리 통째로 갈아만든... ",
# 			"link":"https:\/\/blog.naver.com\/kkungkkang\/223579590141",
# 			"description":"그때 제가 선택한 것이 바로 #김의준고구마 #<b>ABC<\/b>주스 입니다. #<b>ABC<\/b>주스 를 먹게 된 이유는 단순했습니다. 다양한 건강 관련 블로그와 후기에서 <b>ABC<\/b>주스의 효능에 대해 듣고 관심이 생겼습니다. <b>ABC<\/b>주스는 A(사과)... ",
# 			"bloggername":"푸딩하우스",
# 			"bloggerlink":"blog.naver.com\/kkungkkang",
# 			"postdate":"20240910"
# 		},
# 		{
# 			"title":"에이비씨초코 한글한정판 <b>ABC<\/b>초콜렛 글자놀이",
# 			"link":"https:\/\/blog.naver.com\/chocollar\/223600665902",
# 			"description":"좋아하는 <b>ABC<\/b>초콜렛이 한글날을 기념해 에이비씨초코 한글한정판으로 나왔어요! 마트에 갔을 때 없어서 한글날 임박해서 나오려나 싶었는데 계산대 앞에 딱 보이길래 바로 집어 왔어요. 가격은 5,280원 기존 <b>ABC<\/b>... ",
# 			"bloggername":"이니마밍의 연년생 놀이육아",
# 			"bloggerlink":"blog.naver.com\/chocollar",
# 			"postdate":"20240929"
# 		},
# 		{
# 			"title":"<b>abc<\/b>주스 추천 김의준 고구마 통째로 갈아만든 클렌즈주스추천",
# 			"link":"https:\/\/blog.naver.com\/sweetydy\/223578335972",
# 			"description":"통째로 갈아만든 진짜 <b>ABC<\/b>주스 아이들 방학도 끝이 나고 본격적으로 헬스장을 등록하면서 아침 운동을 하고 있는데요, 간단하게 마시고 갈 클렌즈주스추천 김의준고구마 통째로 갈아만든 진짜 <b>ABC<\/b>주스로... ",
# 			"bloggername":"단슌한블로그",
# 			"bloggerlink":"blog.naver.com\/sweetydy",
# 			"postdate":"20240909"
# 		},
# 		{
# 			"title":"팁코 <b>ABC<\/b> 주스 온 가족이 챙겨 먹는 원물 그대로 착즙주스",
# 			"link":"https:\/\/blog.naver.com\/ejr8806\/223505326832",
# 			"description":"잦은 외식과 고기 위주 식사로 야채 섭취가 필요할 때 일일이 챙겨 먹기 쉽지 않더라고요 사과, 당근, 비트 원물 그대로 착즙한 해독주스 아이도 잘 먹는 팁코 <b>ABC<\/b> 주스 소개할게요 :) #팁코<b>ABC<\/b>주스 #<b>ABC<\/b>주스... ",
# 			"bloggername":"제니이이's 소소한 일상 :-)",
# 			"bloggerlink":"blog.naver.com\/ejr8806",
# 			"postdate":"20240708"
# 		},
# 		{
# 			"title":"[김의준고구마 <b>abc<\/b>주스] <b>abc<\/b>주스 추천 아침마다 먹는 건강 주스",
# 			"link":"https:\/\/blog.naver.com\/eunlove111\/223579714263",
# 			"description":"안녕하세요~^^ 로라맘이예요^^ 오늘은 로라맘이 아침마다 챙겨먹을 <b>abc<\/b>주스 추천 하려고 해요!!... 그래서 건강한 다이어트를 해보자는 마음으로 시작해봤습니다 <b>abc<\/b>주스 추천 통째로 갈아만든 <b>ABC<\/b>주스... ",
# 			"bloggername":"은+구=로라남매",
# 			"bloggerlink":"blog.naver.com\/eunlove111",
# 			"postdate":"20240910"
# 		},
# 		{
# 			"title":"팁코 <b>ABC<\/b>주스 NFC착즙 건강주스",
# 			"link":"https:\/\/blog.naver.com\/dodody\/223554071110",
# 			"description":"안녕하세요 요즘 아이와 함께 먹고 있는 팁코 <b>ABC<\/b>주스를 소개하려 합니다 사과, 비트, 당근의 영어 철자를 따서 <b>ABC<\/b>주스라고 불리는데, 색깔도 예쁘고 맛도 적당히 달달하면서 깔끔해서 아이도 어른도 함께... ",
# 			"bloggername":"육아로운 생활",
# 			"bloggerlink":"blog.naver.com\/dodody",
# 			"postdate":"20240820"
# 		},
# 		{
# 			"title":"아침 공복에 누팬트리 유기농 <b>ABC<\/b> 주스 챙기기",
# 			"link":"https:\/\/blog.naver.com\/govira\/223570619194",
# 			"description":"아침 공복에 누팬트리 유기농 <b>ABC<\/b> 주스 챙기기 여름휴가를 다녀와도 아직 끝나지 않은 다욧트~ 간헐적... 바쁜 아침 공복에 가볍고 건강하게 챙기고 싶어서 유기농주스 누팬트리 <b>ABC<\/b> 주스 준비했어요.... ",
# 			"bloggername":"♡ Lovely Kim Tae Eun의 일상",
# 			"bloggerlink":"blog.naver.com\/govira",
# 			"postdate":"20240903"
# 		},
# 		{
# 			"title":"트러블톡톡이 [피캄톡톡이 <b>abc<\/b>클리어톡]",
# 			"link":"https:\/\/blog.naver.com\/ejh03107\/223554276841",
# 			"description":"여드름 균을 99.999% 항균 하는 <b>abc<\/b>클리어톡을 사용해 보았습니다. 여드름이 가라앉는 것 같으면 다시... 여드름 빠르게 잠재우고 싶어서 피캄톡톡이 <b>abc<\/b>클리어톡 트러블톡톡이 사용해 보았어요... ",
# 			"bloggername":"☁️ 둥글게 살자 :) ☁️",
# 			"bloggerlink":"blog.naver.com\/ejh03107",
# 			"postdate":"20240820"
# 		},
# 		{
# 			"title":"<b>abc<\/b>주스 추천 클렌즈주스추천 김의준고구마 통째로 갈아만든... ",
# 			"link":"https:\/\/blog.naver.com\/nuroonge\/223577505405",
# 			"description":"바로 김의준고구마의 통째로 갈아만든 진짜 <b>abc<\/b>주스에요!!!! <b>ABC<\/b>주스 진짜 인기 많았잖아요. 근데 지금도 인기가 많아요 ㅎㅎ 건강에 좋은 주스는 다 좋더라구요 ㅎㅎ 인기 꾸준함 ㅎㅎ <b>abc<\/b>주스란 A 사과, B... ",
# 			"bloggername":"★☆고소한 누룽지☆★",
# 			"bloggerlink":"blog.naver.com\/nuroonge",
# 			"postdate":"20240909"
# 		},
# 		{
# 			"title":"<b>ABC<\/b>주스 클렌즈주스로 다이어트 전 비우기에 딱이야",
# 			"link":"https:\/\/blog.naver.com\/hibiscusbin\/223578891322",
# 			"description":"<b>ABC<\/b>주스 클렌즈주스로 다이어트 전 비우기에 딱이야 다이어트 시작하시는 분들에게 최고인 샐러드판다 <b>ABC<\/b>주스! 클렌즈주스로 먼저 비우기 시작하고 다이어트 하세요:) 안녕하세요 히비스커스입니다. 요즘 또... ",
# 			"bloggername":"히비스커스님의 데일리로그",
# 			"bloggerlink":"blog.naver.com\/hibiscusbin",
# 			"postdate":"20240910"
# 		},
# 		{
# 			"title":"팁코, <b>ABC<\/b>해독주스 사과당근비트 건강간식 <b>ABC<\/b>주스추천",
# 			"link":"https:\/\/blog.naver.com\/minseon35\/223577873329",
# 			"description":"팁코, <b>ABC<\/b>해독주스 추천 안녕하세요 ^^ 요즘 우리가족 건강한 먹거리에 관심이 많은 두 아이의 엄마에요... 팁코, <b>ABC<\/b>해독주스를 마셔보게되었는데 너무 괜찮더라구요 팁코는 워낙 알아주는 맛있는 착즙주스를... ",
# 			"bloggername":"귤이의 집",
# 			"bloggerlink":"blog.naver.com\/minseon35",
# 			"postdate":"20240909"
# 		},
# 		{
# 			"title":"NFC착즙 시원하게 즐기는 팁코 <b>ABC<\/b>주스",
# 			"link":"https:\/\/blog.naver.com\/ymodee\/223555476012",
# 			"description":"몇 해 전부터 <b>ABC<\/b>주스가 핫하길래 사과, 비트, 당근으로 직접 갈아먹어보기도 했는데 재료를 사다... 간편하게 마실 수 있는 팁코 <b>ABC<\/b>주스를 마시고 있어요. 오랜 전통과 역사를 가진 각종 식음료를 제조하는... ",
# 			"bloggername":"앙쥬다미 블로그",
# 			"bloggerlink":"blog.naver.com\/ymodee",
# 			"postdate":"20240821"
# 		},
# 		{
# 			"title":"설빙 메뉴 <b>ABC<\/b>초코쿠키녹차설빙 가격과 후기",
# 			"link":"https:\/\/blog.naver.com\/joop336\/223569574603",
# 			"description":"초코 귀신인 저는 신메뉴 출시 소식을 보자마자 다녀왔습니다~ 이번 설빙 신메뉴는 <b>ABC<\/b>초코쿠키설빙과 <b>ABC<\/b>초코쿠키녹차설빙 두 가지 출시되었는데 그중 녹차로 먹고 온 후기 기록해 볼게요 1. 설빙 신메뉴... ",
# 			"bloggername":"너 리 세 상",
# 			"bloggerlink":"blog.naver.com\/joop336",
# 			"postdate":"20240902"
# 		},
# 		{
# 			"title":"김해스팀세차장 장유스팀세차 <b>ABC<\/b>스팀세차 김해율하점",
# 			"link":"https:\/\/blog.naver.com\/lllllbj\/223560115052",
# 			"description":"김해스팀세차장 <b>ABC<\/b>스팀세차 김해율하점 안녕하세요. 루나입니다 :) 진짜 오랜만에 차를 세차를 맡겼답니다. 김해 율하에 위치한 <b>ABC<\/b>스팀세차 김해율하점에 방문을 했는데요. 미리 예약을 하고 방문을 하시면... ",
# 			"bloggername":"꽃상자 속 작은 이야기 ᥫ᭡ˎˊ˗",
# 			"bloggerlink":"blog.naver.com\/lllllbj",
# 			"postdate":"20240825"
# 		},
# 		{
# 			"title":"팁코 무첨가주스 간편하게 즐기는 <b>ABC<\/b>해독주스",
# 			"link":"https:\/\/blog.naver.com\/cjssus2679\/223552265095",
# 			"description":"<b>ABC<\/b>해독주스가 핫할 때 집에서 만들어 먹어본 1회차 만에 접고 카페 가면 클렌즈주스나 좀 먹어주고 나도 조 간편하게 디톡스 케어 하고싶다! 100% 무첨가주스로 유명한 팁코에서 간편하게 즐길 수 있는 <b>ABC<\/b>해독... ",
# 			"bloggername":"홀로룰루랄라",
# 			"bloggerlink":"blog.naver.com\/cjssus2679",
# 			"postdate":"20240818"
# 		},
# 		{
# 			"title":"<b>ABC<\/b>마트 운동화 종류, 세일",
# 			"link":"https:\/\/blog.naver.com\/kuroinu92\/223575925267",
# 			"description":"<b>ABC<\/b> 마트를 알고 계신가요? 신발을 사러 갈 때 꼭 들르게 되는 곳 중 하나가 바로 <b>ABC<\/b> 마트인데요! <b>ABC<\/b>마트는 정말 다양한 브랜드의 신발을 한곳에서 만나볼 수 있는 멀티샵이에요. 2002년에 한국에 처음 들어왔고... ",
# 			"bloggername":"인간의 드레스룸",
# 			"bloggerlink":"blog.naver.com\/kuroinu92",
# 			"postdate":"20240907"
# 		},
# 		{
# 			"title":"마법소녀기담 <b>ABC<\/b> 89화",
# 			"link":"https:\/\/blog.naver.com\/zoncrown\/223542436625",
# 			"description":"놀라운 결론: 럽코 드가자~ 노벨피아 - 웹만화의 신세계를 만나다 - 마법소녀기담 <b>ABC<\/b> (novelpia.com)... (신기한게, 저번 젖보똥 테라리아 영상은 노딱이 전혀 달리지 않았다고 함) #마법소녀기담<b>ABC<\/b> #만화연재... ",
# 			"bloggername":"zoncrown's SMC",
# 			"bloggerlink":"blog.naver.com\/zoncrown",
# 			"postdate":"20240809"
# 		},
# 		{
# 			"title":"반스 운동화 <b>ABC<\/b>마트 홍대점 신상 VANS 올드스쿨 드레스블루... ",
# 			"link":"https:\/\/blog.naver.com\/leesin8888\/223580369315",
# 			"description":"그리고 오늘 소개해드릴 드레스블루 컬러 같은 경우 <b>ABC<\/b>마트 홍대점에서 만날수 있는데요. 익스클루시브 제품이기 때문에 <b>ABC<\/b>마트와 반스 매장에서만 구매할 수 있다는 점 참고해주세요! <b>ABC<\/b>마트 홍대점 같은... ",
# 			"bloggername":"패션블로거 리군",
# 			"bloggerlink":"blog.naver.com\/leesin8888",
# 			"postdate":"20240911"
# 		},
# 		{
# 			"title":"팁코 <b>ABC<\/b>주스 온가족이 좋아하는 사과당근비트 TIPCO",
# 			"link":"https:\/\/blog.naver.com\/fromantic\/223581344607",
# 			"description":"요즘에 오전에 아이랑 내가 즐겨서 먹는 <b>ABC<\/b>주스가 있다. 바로 팁코 <b>ABC<\/b>주스 ! 우리 아이는 아침에도 먹고 나는 운동 끝나고도 먹고 남편도 입이 심심할때마다 챙겨먹는 사과당근비트 주스이다 :) 간편하게 사과... ",
# 			"bloggername":"Today’s 율라이",
# 			"bloggerlink":"blog.naver.com\/fromantic",
# 			"postdate":"20240912"
# 		},
# 		{
# 			"title":"어린이간식으로 냉장고에 쟁여두었어요 팁코 <b>ABC<\/b>주스",
# 			"link":"https:\/\/blog.naver.com\/april_bom\/223551305583",
# 			"description":"팁코 <b>ABC<\/b> 주스 보여드릴께요 :) 요즘 <b>ABC<\/b>주스가 디톡스주스, 해독주스로 유명한거 다들 알고 계시죠? Apple \/ Beet \/ Carrot 사과 \/ 비트 \/ 당근 오직 세가지 재료만 담은 건강한 주스 팁코 <b>ABC<\/b>주스에요! 사과, 당근... ",
# 			"bloggername":"좌충우돌 육아일기",
# 			"bloggerlink":"blog.naver.com\/april_bom",
# 			"postdate":"20240817"
# 		},
# 		{
# 			"title":"<b>abc<\/b>주스 다이어트 <b>abc<\/b>주스 만들기 김의준고구마 추천",
# 			"link":"https:\/\/blog.naver.com\/frutta520\/223561579491",
# 			"description":"<b>abc<\/b>주스 다이어트 <b>abc<\/b>주스 만들기 김의준고구마 추천 2024년 폭염 속 여름 실내 자전거를 타며 다이어트에 재미 붙인 40대부자엄마입니다 :) 아침마다 식사 대용으로 야채 샐러드를 먹고 있었지요 보다... ",
# 			"bloggername":"40대부자엄마의 알뜰살림♡ 솔직리뷰",
# 			"bloggerlink":"blog.naver.com\/frutta520",
# 			"postdate":"20240826"
# 		},
# 		{
# 			"title":"<b>ABC<\/b>팩토리 사이드 미러 수리 전문점 - BMW 528i 백미러 수리... ",
# 			"link":"https:\/\/blog.naver.com\/naksreview\/223600040936",
# 			"description":"해서 <b>ABC<\/b>팩토리 수리 전문점에 도착! 위치는 서울시 중랑구 면목동에 있다. 흑흑 백미러 아래 껍데기가... <b>ABC<\/b>팩토리 사장님 감사합니다. BMW 백미러 사이드미러 수리점으로 강력 추천한다! #<b>ABC<\/b>팩토리 #사이드미러... ",
# 			"bloggername":"NAK'S REVIEW",
# 			"bloggerlink":"blog.naver.com\/naksreview",
# 			"postdate":"20240928"
# 		},
# 		{
# 			"title":"마법소녀기담 <b>ABC<\/b> 90화",
# 			"link":"https:\/\/blog.naver.com\/zoncrown\/223558436036",
# 			"description":"com) 생방송은 평소대로 저녁8시에 스타트~ #마법소녀기담<b>ABC<\/b> #만화연재 #노벨피아 #마법소녀 #개그 #치지직 #인터넷방송 #눈물점 #부산인디커넥트 #BIC #인디게임",
# 			"bloggername":"zoncrown's SMC",
# 			"bloggerlink":"blog.naver.com\/zoncrown",
# 			"postdate":"20240823"
# 		},
# 		{
# 			"title":"반스 운동화 어센틱 드레스블루 코디, 여자 사이즈 (<b>ABC<\/b>마트... ",
# 			"link":"https:\/\/blog.naver.com\/o_ogirls\/223581053528",
# 			"description":"익스클루시브 컬러인 드레스블루를 <b>ABC<\/b>마트 강남본점에 직접 방문해 만나봤어요 <b>ABC<\/b>마트 강남본점 반스 운동화 한 번도 착용하지 않은 분이 있을까요? 미국에서 런칭해 올해 50주년이된 브랜드로 국내외... ",
# 			"bloggername":"텔라의 패션앤모어",
# 			"bloggerlink":"blog.naver.com\/o_ogirls",
# 			"postdate":"20240912"
# 		},
# 		{
# 			"title":"골뱅이 무침 w <b>ABC<\/b> 비빔양념",
# 			"link":"https:\/\/blog.naver.com\/yoriteacher\/223523852088",
# 			"description":"<b>ABC<\/b> 비빔양념을 넣고 버무려주세요. ❤️ 야채만이 아닌 골뱅이가 들어가니 약간의 식초를... 각종 야채들이 숙성되어 내어주는 풍미가 넘치는 <b>ABC<\/b> 비빔양념. 아삭한 야채들. 쫄깃한 골뱅이. 향긋한 파채. 시원한... ",
# 			"bloggername":"꿈꾸는할멈과 아들쉪의 음식과 사는이야기",
# 			"bloggerlink":"blog.naver.com\/yoriteacher",
# 			"postdate":"20240724"
# 		},
# 		{
# 			"title":"베트남 호치민 <b>ABC<\/b> 베이커리 (ft.베트남의 추석 '쭝투')",
# 			"link":"https:\/\/blog.naver.com\/champ76\/223587735552",
# 			"description":"베트남 친구집에 초대를 받아서 <b>ABC<\/b> 베이커리에서 월병을 사가지고 갔다 베트남은 추석이 따로 쉬는... 귀엽구만 <b>ABC<\/b> 베이커리 한 번 가보자고!!! 뭐야!! 사진이 흔들린줄도 몰랐네 #<b>ABC<\/b>베이커리 #베트남추석명절... ",
# 			"bloggername":"추억은 방울방울",
# 			"bloggerlink":"blog.naver.com\/champ76",
# 			"postdate":"20240918"
# 		},
# 		{
# 			"title":"엔유씨 착즙기 - 착즙 주스 만드는 재미 : 포도주스, <b>abc<\/b>주스... ",
# 			"link":"https:\/\/blog.naver.com\/wod337\/223585675443",
# 			"description":"착즙이 잘 되고 있어서 <b>abc<\/b> 주스랑 cca 주스 자주 만들어 마시는데, 요즘 사과 너무 비쌈. 포도 한 상자... #엔유씨착즙기 #엔유씨 #<b>abc<\/b>주스 #휴롬착즙기 #포도착즙 #비트착즙 #포도쥬스만들기 #비트쥬스",
# 			"bloggername":"꿈꾸는 미야",
# 			"bloggerlink":"blog.naver.com\/wod337",
# 			"postdate":"20240916"
# 		},
# 		{
# 			"title":"설빙 콜라보 신메뉴 <b>ABC<\/b>초코쿠키설빙과 <b>ABC<\/b>초코쿠키녹차설빙... ",
# 			"link":"https:\/\/blog.naver.com\/hans_way\/223579568528",
# 			"description":"혈관에 초코를 좀 흐르게 하고 싶다면 설빙에 <b>ABC<\/b>초코쿠키와 콜라보 한 신메뉴 <b>ABC<\/b>초코쿠키설빙과 녹차설빙 드셔보시면 좋을 것 같다. 총 다섯가지의 초코 관련 토핑이 가득가득 들어간 우유빙수라서... ",
# 			"bloggername":"수지맞은 날",
# 			"bloggerlink":"blog.naver.com\/hans_way",
# 			"postdate":"20240910"
# 		},
# 		{
# 			"title":"<b>ABC<\/b>초코쿠키설빙 배달 후기",
# 			"link":"https:\/\/blog.naver.com\/ks1058\/223590877566",
# 			"description":"<b>ABC<\/b> 초코쿠키설빙 내돈내산 배달후기 설빙 신제품이 나왔다고 해서 명절연휴 마지막날 배달해 본 <b>ABC<\/b> 초코쿠키설빙 내 배민에 담았다가 남편이 배민에 5천원 할인쿠폰있어 12.100원에 먹게 되어 기분좋았던... ",
# 			"bloggername":"직접 맛보고 체험하고 리뷰하기!",
# 			"bloggerlink":"blog.naver.com\/ks1058",
# 			"postdate":"20240921"
# 		},
# 		{
# 			"title":"마법소녀기담 <b>ABC<\/b> 93화 +번외 8",
# 			"link":"https:\/\/blog.naver.com\/zoncrown\/223606595757",
# 			"description":"살자무브가 담긴 놀라운 썸네일의 다음화는 평소대로 2주간 노벨피아 독점으로 공개됩니다. #마법소녀기담<b>ABC<\/b> #만화연재 #노벨피아 #마법소녀 #러브코미디 #개그 #회상 #번외편 #참피 #우마무스메 #해피캣",
# 			"bloggername":"zoncrown's SMC",
# 			"bloggerlink":"blog.naver.com\/zoncrown",
# 			"postdate":"20241004"
# 		},
# 		{
# 			"title":"(Python) 추상클래스 구현, from <b>abc<\/b> import <b>ABC<\/b>",
# 			"link":"https:\/\/blog.naver.com\/nabilera1\/223595768471",
# 			"description":"#파이썬기초 #수업자료 #학습자료 #메모 파이썬 추상클래스 만들기 from <b>abc<\/b> import <b>ABC<\/b> <b>abc<\/b>는 &quot;Abstract Base Classes&quot;의 약자로, 파이썬에서 추상 클래스를 정의할 때 사용하는 모듈입니다. 추상 클래스는... ",
# 			"bloggername":"김동균의 소프트웨어아카데미(2004~ )",
# 			"bloggerlink":"blog.naver.com\/nabilera1",
# 			"postdate":"20240925"
# 		},
# 		{
# 			"title":"일본 피크닉 일본운전 <b>ABC<\/b>마트 운동화 질유산균 락토바이브... ",
# 			"link":"https:\/\/blog.naver.com\/pinkneko84\/223587349066",
# 			"description":"ㅋㅋㅋ #인형뽑기 #게임센터 #<b>abc<\/b>마트 콩찌 운동화 구매 발볼 넓은게 좋다며 3E 신발 찾아서 구매 난리났음 세탁했는데 옷에 왠 종이들이 가득 알고보니 콩남매들이 게임한다고 넣어둔 카드가 세탁기에 그대로... ",
# 			"bloggername":"네코 콩남매일상",
# 			"bloggerlink":"blog.naver.com\/pinkneko84",
# 			"postdate":"20240918"
# 		},
# 		{
# 			"title":"설빙 신메뉴 <b>ABC<\/b> 초코쿠키 설빙 내돈내산",
# 			"link":"https:\/\/blog.naver.com\/pigprincessofpigland\/223584627283",
# 			"description":"신메뉴 도전하는 것을 좋아하는 나는 이번 설빙의 신메뉴인 <b>ABC<\/b> 초코쿠키 설빙을 먹으러 갔다... 롯데의 <b>ABC<\/b> 초코 쿠키가 콜라보 해서 만들어진 <b>ABC<\/b> 초코쿠키 설빙 <b>ABC<\/b> 초코쿠키 설빙 기본 초코맛뿐만 아니라 <b>ABC<\/b>... ",
# 			"bloggername":"제주 돼지나라 먹보공주",
# 			"bloggerlink":"blog.naver.com\/pigprincessofpigland",
# 			"postdate":"20240915"
# 		},
# 		{
# 			"title":"마법소녀기담 <b>ABC<\/b> 92화",
# 			"link":"https:\/\/blog.naver.com\/zoncrown\/223590375848",
# 			"description":"게임연재글 준비하던게 추석일정+디시 장문글 업로드 찐빠로 좀 더 걸리게 될 예정 ㅈㅅ #마법소녀기담<b>ABC<\/b> #만화연재 #노벨피아 #마법소녀 #러브코미디 #시리어스",
# 			"bloggername":"zoncrown's SMC",
# 			"bloggerlink":"blog.naver.com\/zoncrown",
# 			"postdate":"20240920"
# 		},
# 		{
# 			"title":"설빙 신메뉴 <b>ABC<\/b>초코쿠키설빙 녹차 내돈내산 후기",
# 			"link":"https:\/\/blog.naver.com\/kangcoach_\/223564418638",
# 			"description":"<b>ABC<\/b>초코쿠키랑 콜라보라니,,,,  이건 바로 먹어봐야겠다 싶어서 오늘 출시한 <b>ABC<\/b>초코쿠키 설빙 먹고 후기 들고왔습니다 ㅎㅎ 초코쿠키설빙 출시! <b>ABC<\/b>초코쿠키녹차설빙 13,900원 바닐라랑 녹차가 있었는데... ",
# 			"bloggername":"냠뇸 먹일기 모음집",
# 			"bloggerlink":"blog.naver.com\/kangcoach_",
# 			"postdate":"20240828"
# 		},
# 		{
# 			"title":"39편 세븐일레븐 스무디, 사쿠라기초역, 콜레트 마레, <b>ABC<\/b>마트",
# 			"link":"https:\/\/blog.naver.com\/classicnwine\/223609799042",
# 			"description":"<b>ABC<\/b>마트도 그냥 지나칠 수 없습니다. 새로운 신발을 사야죠! 신발을 신고 잘 맞는지 돌아다녀 봅니다. 무지도 둘러보고, 스위트 매장들로 방문해 봅니다. 쇼핑할 때는 지치지 않습니다. (지치지마! 우리는... ",
# 			"bloggername":"린사랑의 육아여행 \/ 린사랑의 서재",
# 			"bloggerlink":"blog.naver.com\/classicnwine",
# 			"postdate":"20241007"
# 		},
# 		{
# 			"title":"[설빙 메뉴 추천] 설빙 수원역점, 신메뉴 <b>ABC<\/b>초코쿠키 솔직... ",
# 			"link":"https:\/\/kwoong.tistory.com\/249",
# 			"description":"'<b>ABC<\/b>초코쿠키설빙' 저는 초코 귀신이기 때문에 고민 없이 바로 주문해 보았습니다. 설빙 수원역점... 메뉴명 <b>ABC<\/b>초코쿠키설빙 13,900원 해당 매장은 키오스크가 없어서 포스에서 주문을 하시면 되고 주문을 하면... ",
# 			"bloggername":"이건빵의 맛집, 제품 소개",
# 			"bloggerlink":"https:\/\/kwoong.tistory.com\/",
# 			"postdate":"20240903"
# 		}
# 	]
# }

# %%
res_json = json.loads(response_body)
df = pd.DataFrame(res_json['items'])
print(df.shape)
df
# Out:
# (100, 6)
#                                           title  \
# 0             장충동 <b>스타벅스</b> 장충라운지 R점 주차 및 웨이팅
# 1             <b>스타벅스</b> 10월 가을 신메뉴 마롱 헤이즐넛 라떼
# 2                <b>스타벅스</b> 버디패스 직접 써본 내돈내산 후기
# 3   <b>스타벅스</b> 플레이모빌 2024 2주차 버디 킴 빅터 매리 구매 후기
# 4           <b>스타벅스</b> 마롱 헤이즐넛 라떼 10월 신메뉴 맛 소감
# ..                                          ...
# 95                 계곡이 있는 <b>스타벅스</b> 용인고기동유원지점
# 96        <b>스타벅스</b> 세븐 레이어 가나슈 케이크 홀케이크 주문 후기
# 97            #225: <b>스타벅스</b> 피규어 어쩜 이리 귀여워~?
# 98        4주차 9월 맛집탐방 인크커피  홍종흔베이커리 <b>스타벅스</b>
# 99                       9월 마지막 주 - <b>스타벅스</b>
#
#                                                 link  \
# 0         https://blog.naver.com/luvzi-/223604647250
# 1     https://blog.naver.com/darkyoon85/223600579975
# 2        https://blog.naver.com/sohwa91/223603237044
# 3       https://blog.naver.com/kastro83/223609693616
# 4      https://blog.naver.com/lovableje/223598182604
# ..                                               ...
# 95    https://blog.naver.com/sweetssoli/223595193710
# 96  https://blog.naver.com/naturalree12/223606794969
# 97  https://blog.naver.com/happygirl718/223604570598
# 98        https://blog.naver.com/nako03/223600969786
# 99   https://blog.naver.com/lovelyj9123/223600404772
#
#                                           description  \
# 0   장충동 카페 <b>스타벅스</b> 스페셜스토어 장충라운지R점 * 주소 : 서울시 중...
# 1   마롱 헤이즐넛 라떼 <b>스타벅스</b> 신메뉴 <b>스타벅스</b> 신메뉴 소개해...
# 2   오늘은 드디어 <b>스타벅스</b> 버디패스 출시되는 날!! 사실 저는 <b>스타벅...
# 3   <b>스타벅스</b> 플레이모빌 2024 2주차 버디인 킴 빅터 매리 구매 후기입니...
# 4   맞이하여 <b>스타벅스</b>에서도 신메뉴들이 어텀스러운 분위기로 출시되었더라고요....
# ..                                                ...
# 95  따끈따끈한 신상 <b>스타벅스</b> 쿠폰 쓸 겸 드라이브할 겸 겸사겸사 갔다 온 ...
# 96  며칠전 오뜬금양 생일이었어요 생일을 맞이하여 풀빌라가서 신나게 1박2일 즐겼답니다 ...
# 97  ● 2024.10.2.(수) ● 날 씨 : 진짜 가을 날씨~ ● #225 : <b>...
# 98  <b>스타벅스</b> <b>스타벅스</b> 신메뉴인 블랙글레이즈드라떼는 먹었다. 글...
# 99  이번주에는 무려 다섯 번이나 <b>스타벅스</b>를 찾았다. 세계에서 두번째로 높은...
#
#                      bloggername                  bloggerlink  postdate
# 0                            개 집        blog.naver.com/luvzi-  20241002
# 1                    다크윤의 맛집이야기♥    blog.naver.com/darkyoon85  20241001
# 2                ˚✧₊❁⁎솨의봄날⁎⁺˳❁✧༚       blog.naver.com/sohwa91  20241001
# 3                 한가한 오후는 녹차와 함께      blog.naver.com/kastro83  20241007
# 4                      쯘이의 꽃같은일상     blog.naver.com/lovableje  20240927
# ..                           ...                          ...       ...
# 95                    기억하고 싶은 기록    blog.naver.com/sweetssoli  20240924
# 96             Always with you ❤  blog.naver.com/naturalree12  20241004
# 97  요리하기 좋아하는 워킹맘 ::예스맘의 워킹맘다이어리  blog.naver.com/happygirl718  20241002
# 98                       달티의 맛맛맛        blog.naver.com/nako03  20240929
# 99     소소한 일상을 기록하는, 한을이의 주절주절로그   blog.naver.com/lovelyj9123  20240929
#
# [100 rows x 6 columns]

# %%
base_url = 'https://openapi.naver.com/v1/search/blog'
p = {
    'query':'abc',
    'display':100,
    'start':1
}
enc_params = urllib.parse.urlencode(p)
url = f'{base_url}?{enc_params}'
url
# Out:
# 'https://openapi.naver.com/v1/search/blog?query=abc&display=100&start=1'

# %%
# Out:
# 'query=abc&display=100&start=1'
