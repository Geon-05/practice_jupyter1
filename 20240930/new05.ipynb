# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# %%
a=['a','b','c']
y=[10,20,30]
plt.plot(a,y)

# %%
a=['aaaa','bbbb','cccc']
y=[10,20,30]
plt.plot(a,y)

# %%
a=['aaaa','bbbb','cccc']
y=[10,20,30]
plt.plot(a,y)
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2], [Text(0, 0, 'aaaa'), Text(1, 0, 'bbbb'), Text(2, 0, 'cccc')])

# %%
a=['aaaa','bbbb','cccc']
y=[10,20,30]
plt.plot(a,y)
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2], [Text(0, 0, 'aaaa'), Text(1, 0, 'bbbb'), Text(2, 0, 'cccc')])

# %%
a=['aaaa','bbbb','cccc']
y=[10,20,30]
k=[15,27,10]
plt.plot(a,y,label='abc')
plt.plot(a,k,label='bbb')
plt.ylim(0,50)
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
a = np.arange(5)
b = a * 2
c = a * 2 + 1
plt.plot(a,'r-o')
plt.plot(b,':^b')
plt.plot(c,'g--D')
plt.grid()
