# %%
pwd
# Out:
# 'C:\\Users\\go121\\practice_jupyter\\py\\데이터분석 및 시각화\\05 워드클라우드'

# %%
from konlpy.tag import Okt
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rc('axes', unicode_minus=False)
from collections import Counter

# %%
sample = pd.read_csv('./전처리_샘플뉴스.csv')
print(sample.shape)
sample.head()
# Out:
# (5, 5)
#                                    title  \
# 0  방역 2.5단계 뒤 을씨년스럽게 변한 '스벅'···별천지된 '파바'
# 1          "기적 같은 선방"이라지만...현장은 성한 곳이 없다
# 2           13일까지 장맛비… 사흘간 물폭탄 사망·실종 25명
# 3             최악 장마에 태풍까지…  내일까지 최고 300㎜
# 4                       은행 예금금리 사상 첫 0%대
#
#                                                 text  \
# 0  서울의 밤이 달라졌다. 수도권을 대상으로 이른바 ‘사회적 거리두기 2.5단계’가 시...
# 1  “50년 동안 사업하면서 소위 ‘깡통’을 세 번 차고도 재기했는데, 이번 위기는 정...
# 2  곳곳 수해 초비상 \r\n\r\n    3일 오전 충남 천안과 아산지역에 호우경보가...
# 3  예측하기 어려운 ‘물폭탄’을 동반한 장마가 유례없이 길어지고 있다. 설상가상으로 9...
# 4  대출금리도 2.72% 사상최저\r\n\r\n\r\n\r\n\t\t\t\t은행 예금에...
#
#                                                  url media        date
# 0  https://news.naver.com/main/read.nhn?mode=LPOD...  중앙일보  2020-08-31
# 1  https://news.naver.com/main/read.nhn?mode=LPOD...  한국일보  2020-08-03
# 2  https://news.naver.com/main/read.nhn?mode=LPOD...  세계일보  2020-08-04
# 3  https://news.naver.com/main/read.nhn?mode=LPOD...  국민일보  2020-08-10
# 4  https://news.naver.com/main/read.nhn?mode=LPOD...  조선일보  2020-08-01

# %%
okt = Okt()
words = okt.nouns(sample['text'][2])
words[:10]
# Out:
# ['곳곳', '수해', '초비상', '오전', '충남', '천안', '아산', '지역', '호우경보', '발령']

# %%
str_words = ' '.join(words)
str_words[:10]
# Out:
# '곳곳 수해 초비상 '

# %%
wc=WordCloud(font_path="C:/windows/fonts/malgun.ttf",
            background_color='black',
            width=500,
            height=500,
            max_words=100,
            max_font_size=200)
            #stopwords = stopwords)
wc=wc.generate(str_words)
wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
#matplotlib로 시작화(2)
plt.figure(figsize = (12, 12))
plt.imshow(wc) #interpolation = "bilinear")
plt.axis("off")
plt.show()

# %%
counter = Counter(words)
counter
# Out:
# Counter({'명': 12,
#          '날': 5,
#          '등': 5,
#          '피해': 5,
#          '경기': 5,
#          '지역': 4,
#          '오후': 4,
#          '중부지방': 4,
#          '오전': 3,
#          '침수': 3,
#          '비': 3,
#          '것': 3,
#          '중': 3,
#          '집중호우': 3,
#          '토사': 3,
#          '산사태': 3,
#          '펜션': 3,
#          '강원': 3,
#          '발생': 3,
#          '하천': 3,
#          '물': 3,
#          '건': 3,
#          '곳': 3,
#          '충남': 2,
#          '아산': 2,
#          '발령': 2,
#          '도로': 2,
#          '사흘': 2,
#          '인명': 2,
#          '대본': 2,
#          '현재': 2,
#          '가평': 2,
#          '포천': 2,
#          '과': 2,
#          '후': 2,
#          '소방': 2,
#          '당국': 2,
#          '근로자': 2,
#          '가평읍': 2,
#          '산': 2,
#          '유리': 2,
#          '주인': 2,
#          '이': 2,
#          '명의': 2,
#          '가평군': 2,
#          '실종자': 2,
#          '경기도': 2,
#          '범람': 2,
#          '주택': 2,
#          '달': 2,
#          '단계': 2,
#          '상황': 2,
#          '서울': 2,
#          '영서': 2,
#          '충청': 2,
#          '북부': 2,
#          '이상': 2,
#          '곳곳': 1,
#          '수해': 1,
#          '초비상': 1,
#          '천안': 1,
#          '호우경보': 1,
#          '가운데': 1,
#          '아산시': 1,
#          '온천': 1,
#          '관광': 1,
#          '호텔': 1,
#          '사거리': 1,
#          '독자': 1,
#          '제공': 1,
#          '뉴시스': 1,
#          '지난': 1,
#          '동안': 1,
#          '물폭탄': 1,
#          '수도권': 1,
#          '재산': 1,
#          '속출': 1,
#          '예보': 1,
#          '각별': 1,
#          '주의': 1,
#          '요구': 1,
#          '중앙': 1,
#          '재난': 1,
#          '안전': 1,
#          '대책': 1,
#          '본부': 1,
#          '각': 1,
#          '지방자치단체': 1,
#          '계속': 1,
#          '게릴라': 1,
#          '평택': 1,
#          '실종': 1,
#          '신고': 1,
#          '사람': 1,
#          '평택시': 1,
#          '청북읍': 1,
#          '사리': 1,
#          '반도체': 1,
#          '장비': 1,
#          '부품': 1,
#          '공장': 1,
#          '건물': 1,
#          '뒤편': 1,
#          '야산': 1,
#          '가건물': 1,
#          '천막': 1,
#          '사고': 1,
#          '만인': 1,
#          '낮': 1,
#          '씨': 1,
#          '구조해': 1,
#          '인근': 1,
#          '병원': 1,
#          '끝내': 1,
#          '무동': 1,
#          '여': 1,
#          '딸': 1,
#          '손자': 1,
#          '직원': 1,
#          '베트남인': 1,
#          '매몰': 1,
#          '가족': 1,
#          '시신': 1,
#          '수습': 1,
#          '밭': 1,
#          '급류': 1,
#          '린': 1,
#          '청평면': 1,
#          '농민': 1,
#          '사망자': 1,
#          '더': 1,
#          '늘': 1,
#          '수': 1,
#          '강타': 1,
#          '사망': 1,
#          '중장비': 1,
#          '동원': 1,
#          '작업': 1,
#          '벌이': 1,
#          '뉴스': 1,
#          '충북': 1,
#          '가구': 1,
#          '재민': 1,
#          '제방': 1,
#          '일시': 1,
#          '대피': 1,
#          '인원': 1,
#          '시설': 1,
#          '채': 1,
#          '비닐하우스': 1,
#          '동이': 1,
#          '저수지': 1,
#          '교량': 1,
#          '파손': 1,
#          '농경': 1,
#          '전국': 1,
#          '개': 1,
#          '댐': 1,
#          '충주댐': 1,
#          '대청댐': 1,
#          '감당': 1,
#          '방류': 1,
#          '여주': 1,
#          '청미': 1,
#          '복': 1,
#          '남양주': 1,
#          '왕숙천': 1,
#          '영평': 1,
#          '홍수': 1,
#          '보가': 1,
#          '전날': 1,
#          '기해': 1,
#          '위기': 1,
#          '최고': 1,
#          '수준': 1,
#          '심각': 1,
#          '로': 1,
#          '격상': 1,
#          '대처': 1,
#          '및': 1,
#          '긴급': 1,
#          '점검': 1,
#          '회의': 1,
#          '문재인': 1,
#          '대통령': 1,
#          '보고': 1,
#          '추가': 1,
#          '정부': 1,
#          '지자체': 1,
#          '총력': 1,
#          '고': 1,
#          '당부': 1,
#          '기상청': 1,
#          '제': 1,
#          '호': 1,
#          '태풍': 1,
#          '하구핏': 1,
#          '의': 1,
#          '영향': 1,
#          '중심': 1,
#          '예상': 1,
#          '강수량': 1,
#          '서해': 1,
#          '도': 1,
#          '강원영동': 1,
#          '남부': 1,
#          '경북': 1,
#          '지방': 1,
#          '줄곧': 1,
#          '송민섭': 1,
#          '남혜정': 1,
#          '박현준': 1,
#          '기자': 1,
#          '세상': 1,
#          '눈': 1,
#          '세계': 1,
#          '일보': 1})

# %%
wc = WordCloud("C:/windows/fonts/malgun.ttf",
               background_color = "white",
               max_words = 2000)
               #stopwords = stopwords)
wc = wc.generate_from_frequencies(counter) #w_dict는 {단어:빈도수}형식의 딕셔너리
wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200>

# %%
tmp = sorted(counter.items(),key=lambda x:x[1], reverse=True)[:20]

# %%
pd.DataFrame(tmp).set_index(0).plot(kind='bar')
# Out:
# <Axes: xlabel='0'>

# %%
[w for w, c in tmp]
# Out:
# ['명',
#  '날',
#  '등',
#  '피해',
#  '경기',
#  '지역',
#  '오후',
#  '중부지방',
#  '오전',
#  '침수',
#  '비',
#  '것',
#  '중',
#  '집중호우',
#  '토사',
#  '산사태',
#  '펜션',
#  '강원',
#  '발생',
#  '하천']

# %%
wc.words_
# Out:
# {'명': 1.0,
#  '날': 0.4166666666666667,
#  '등': 0.4166666666666667,
#  '피해': 0.4166666666666667,
#  '경기': 0.4166666666666667,
#  '지역': 0.3333333333333333,
#  '오후': 0.3333333333333333,
#  '중부지방': 0.3333333333333333,
#  '오전': 0.25,
#  '침수': 0.25,
#  '비': 0.25,
#  '것': 0.25,
#  '중': 0.25,
#  '집중호우': 0.25,
#  '토사': 0.25,
#  '산사태': 0.25,
#  '펜션': 0.25,
#  '강원': 0.25,
#  '발생': 0.25,
#  '하천': 0.25,
#  '물': 0.25,
#  '건': 0.25,
#  '곳': 0.25,
#  '충남': 0.16666666666666666,
#  '아산': 0.16666666666666666,
#  '발령': 0.16666666666666666,
#  '도로': 0.16666666666666666,
#  '사흘': 0.16666666666666666,
#  '인명': 0.16666666666666666,
#  '대본': 0.16666666666666666,
#  '현재': 0.16666666666666666,
#  '가평': 0.16666666666666666,
#  '포천': 0.16666666666666666,
#  '과': 0.16666666666666666,
#  '후': 0.16666666666666666,
#  '소방': 0.16666666666666666,
#  '당국': 0.16666666666666666,
#  '근로자': 0.16666666666666666,
#  '가평읍': 0.16666666666666666,
#  '산': 0.16666666666666666,
#  '유리': 0.16666666666666666,
#  '주인': 0.16666666666666666,
#  '이': 0.16666666666666666,
#  '명의': 0.16666666666666666,
#  '가평군': 0.16666666666666666,
#  '실종자': 0.16666666666666666,
#  '경기도': 0.16666666666666666,
#  '범람': 0.16666666666666666,
#  '주택': 0.16666666666666666,
#  '달': 0.16666666666666666,
#  '단계': 0.16666666666666666,
#  '상황': 0.16666666666666666,
#  '서울': 0.16666666666666666,
#  '영서': 0.16666666666666666,
#  '충청': 0.16666666666666666,
#  '북부': 0.16666666666666666,
#  '이상': 0.16666666666666666,
#  '곳곳': 0.08333333333333333,
#  '수해': 0.08333333333333333,
#  '초비상': 0.08333333333333333,
#  '천안': 0.08333333333333333,
#  '호우경보': 0.08333333333333333,
#  '가운데': 0.08333333333333333,
#  '아산시': 0.08333333333333333,
#  '온천': 0.08333333333333333,
#  '관광': 0.08333333333333333,
#  '호텔': 0.08333333333333333,
#  '사거리': 0.08333333333333333,
#  '독자': 0.08333333333333333,
#  '제공': 0.08333333333333333,
#  '뉴시스': 0.08333333333333333,
#  '지난': 0.08333333333333333,
#  '동안': 0.08333333333333333,
#  '물폭탄': 0.08333333333333333,
#  '수도권': 0.08333333333333333,
#  '재산': 0.08333333333333333,
#  '속출': 0.08333333333333333,
#  '예보': 0.08333333333333333,
#  '각별': 0.08333333333333333,
#  '주의': 0.08333333333333333,
#  '요구': 0.08333333333333333,
#  '중앙': 0.08333333333333333,
#  '재난': 0.08333333333333333,
#  '안전': 0.08333333333333333,
#  '대책': 0.08333333333333333,
#  '본부': 0.08333333333333333,
#  '각': 0.08333333333333333,
#  '지방자치단체': 0.08333333333333333,
#  '계속': 0.08333333333333333,
#  '게릴라': 0.08333333333333333,
#  '평택': 0.08333333333333333,
#  '실종': 0.08333333333333333,
#  '신고': 0.08333333333333333,
#  '사람': 0.08333333333333333,
#  '평택시': 0.08333333333333333,
#  '청북읍': 0.08333333333333333,
#  '사리': 0.08333333333333333,
#  '반도체': 0.08333333333333333,
#  '장비': 0.08333333333333333,
#  '부품': 0.08333333333333333,
#  '공장': 0.08333333333333333,
#  '건물': 0.08333333333333333,
#  '뒤편': 0.08333333333333333,
#  '야산': 0.08333333333333333,
#  '가건물': 0.08333333333333333,
#  '천막': 0.08333333333333333,
#  '사고': 0.08333333333333333,
#  '만인': 0.08333333333333333,
#  '낮': 0.08333333333333333,
#  '씨': 0.08333333333333333,
#  '구조해': 0.08333333333333333,
#  '인근': 0.08333333333333333,
#  '병원': 0.08333333333333333,
#  '끝내': 0.08333333333333333,
#  '무동': 0.08333333333333333,
#  '여': 0.08333333333333333,
#  '딸': 0.08333333333333333,
#  '손자': 0.08333333333333333,
#  '직원': 0.08333333333333333,
#  '베트남인': 0.08333333333333333,
#  '매몰': 0.08333333333333333,
#  '가족': 0.08333333333333333,
#  '시신': 0.08333333333333333,
#  '수습': 0.08333333333333333,
#  '밭': 0.08333333333333333,
#  '급류': 0.08333333333333333,
#  '린': 0.08333333333333333,
#  '청평면': 0.08333333333333333,
#  '농민': 0.08333333333333333,
#  '사망자': 0.08333333333333333,
#  '더': 0.08333333333333333,
#  '늘': 0.08333333333333333,
#  '수': 0.08333333333333333,
#  '강타': 0.08333333333333333,
#  '사망': 0.08333333333333333,
#  '중장비': 0.08333333333333333,
#  '동원': 0.08333333333333333,
#  '작업': 0.08333333333333333,
#  '벌이': 0.08333333333333333,
#  '뉴스': 0.08333333333333333,
#  '충북': 0.08333333333333333,
#  '가구': 0.08333333333333333,
#  '재민': 0.08333333333333333,
#  '제방': 0.08333333333333333,
#  '일시': 0.08333333333333333,
#  '대피': 0.08333333333333333,
#  '인원': 0.08333333333333333,
#  '시설': 0.08333333333333333,
#  '채': 0.08333333333333333,
#  '비닐하우스': 0.08333333333333333,
#  '동이': 0.08333333333333333,
#  '저수지': 0.08333333333333333,
#  '교량': 0.08333333333333333,
#  '파손': 0.08333333333333333,
#  '농경': 0.08333333333333333,
#  '전국': 0.08333333333333333,
#  '개': 0.08333333333333333,
#  '댐': 0.08333333333333333,
#  '충주댐': 0.08333333333333333,
#  '대청댐': 0.08333333333333333,
#  '감당': 0.08333333333333333,
#  '방류': 0.08333333333333333,
#  '여주': 0.08333333333333333,
#  '청미': 0.08333333333333333,
#  '복': 0.08333333333333333,
#  '남양주': 0.08333333333333333,
#  '왕숙천': 0.08333333333333333,
#  '영평': 0.08333333333333333,
#  '홍수': 0.08333333333333333,
#  '보가': 0.08333333333333333,
#  '전날': 0.08333333333333333,
#  '기해': 0.08333333333333333,
#  '위기': 0.08333333333333333,
#  '최고': 0.08333333333333333,
#  '수준': 0.08333333333333333,
#  '심각': 0.08333333333333333,
#  '로': 0.08333333333333333,
#  '격상': 0.08333333333333333,
#  '대처': 0.08333333333333333,
#  '및': 0.08333333333333333,
#  '긴급': 0.08333333333333333,
#  '점검': 0.08333333333333333,
#  '회의': 0.08333333333333333,
#  '문재인': 0.08333333333333333,
#  '대통령': 0.08333333333333333,
#  '보고': 0.08333333333333333,
#  '추가': 0.08333333333333333,
#  '정부': 0.08333333333333333,
#  '지자체': 0.08333333333333333,
#  '총력': 0.08333333333333333,
#  '고': 0.08333333333333333,
#  '당부': 0.08333333333333333,
#  '기상청': 0.08333333333333333,
#  '제': 0.08333333333333333,
#  '호': 0.08333333333333333,
#  '태풍': 0.08333333333333333,
#  '하구핏': 0.08333333333333333,
#  '의': 0.08333333333333333,
#  '영향': 0.08333333333333333,
#  '중심': 0.08333333333333333,
#  '예상': 0.08333333333333333,
#  '강수량': 0.08333333333333333,
#  '서해': 0.08333333333333333,
#  '도': 0.08333333333333333,
#  '강원영동': 0.08333333333333333,
#  '남부': 0.08333333333333333,
#  '경북': 0.08333333333333333,
#  '지방': 0.08333333333333333,
#  '줄곧': 0.08333333333333333,
#  '송민섭': 0.08333333333333333,
#  '남혜정': 0.08333333333333333,
#  '박현준': 0.08333333333333333,
#  '기자': 0.08333333333333333,
#  '세상': 0.08333333333333333,
#  '눈': 0.08333333333333333,
#  '세계': 0.08333333333333333,
#  '일보': 0.08333333333333333}
