# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# %%
df1 = pd.read_csv('./data/cctv_in_seoul.csv')
df1 = df1.set_index('기관명')
df1
# Out:
#         소계  2013년도 이전  2014년  2015년  2016년
# 기관명
# 강남구   3238       1292    430    584    932
# 강동구   1010        379     99    155    377
# 강북구    831        369    120    138    204
# 강서구    911        388    258    184     81
# 관악구   2109        846    260    390    613
# 광진구    878        573     78     53    174
# 구로구   1884       1142    173    246    323
# 금천구   1348        674     51    269    354
# 노원구   1566        542     57    451    516
# 도봉구    825        238    159     42    386
# 동대문구  1870       1070     23    198    579
# 동작구   1302        544    341    103    314
# 마포구    980        314    118    169    379
# 서대문구  1254        844     50     68    292
# 서초구   2297       1406    157    336    398
# 성동구   1327        730     91    241    265
# 성북구   1651       1009     78    360    204
# 송파구   1081        529     21     68    463
# 양천구   2482       1843    142     30    467
# 영등포구  1277        495    214    195    373
# 용산구   2096       1368    218    112    398
# 은평구   2108       1138    224    278    468
# 종로구   1619        464    314    211    630
# 중구    1023        413    190     72    348
# 중랑구    916        509    121    177    109

# %%
df1['2014년'].plot(kind='bar')
# Out:
# <Axes: xlabel='기관명'>

# %%
df1.head()
# Out:
#        소계  2013년도 이전  2014년  2015년  2016년
# 기관명
# 강남구  3238       1292    430    584    932
# 강동구  1010        379     99    155    377
# 강북구   831        369    120    138    204
# 강서구   911        388    258    184     81
# 관악구  2109        846    260    390    613

# %%
df1 = df1.reset_index()
df1
# Out:
#     index   기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0       0   강남구  3238       1292    430    584    932
# 1       1   강동구  1010        379     99    155    377
# 2       2   강북구   831        369    120    138    204
# 3       3   강서구   911        388    258    184     81
# 4       4   관악구  2109        846    260    390    613
# 5       5   광진구   878        573     78     53    174
# 6       6   구로구  1884       1142    173    246    323
# 7       7   금천구  1348        674     51    269    354
# 8       8   노원구  1566        542     57    451    516
# 9       9   도봉구   825        238    159     42    386
# 10     10  동대문구  1870       1070     23    198    579
# 11     11   동작구  1302        544    341    103    314
# 12     12   마포구   980        314    118    169    379
# 13     13  서대문구  1254        844     50     68    292
# 14     14   서초구  2297       1406    157    336    398
# 15     15   성동구  1327        730     91    241    265
# 16     16   성북구  1651       1009     78    360    204
# 17     17   송파구  1081        529     21     68    463
# 18     18   양천구  2482       1843    142     30    467
# 19     19  영등포구  1277        495    214    195    373
# 20     20   용산구  2096       1368    218    112    398
# 21     21   은평구  2108       1138    224    278    468
# 22     22   종로구  1619        464    314    211    630
# 23     23    중구  1023        413    190     72    348
# 24     24   중랑구   916        509    121    177    109

# %%
df1['2014년'].plot(kind='bar')
# Out:
# <Axes: xlabel='기관명'>

# %%
df1 = df1.set_index('기관명')

# %%
df1.plot(kind='bar')
# Out:
# <Axes: xlabel='기관명'>

# %%
df1
# Out:
#       index    소계  2013년도 이전  2014년  2015년  2016년
# 기관명
# 강남구       0  3238       1292    430    584    932
# 강동구       1  1010        379     99    155    377
# 강북구       2   831        369    120    138    204
# 강서구       3   911        388    258    184     81
# 관악구       4  2109        846    260    390    613
# 광진구       5   878        573     78     53    174
# 구로구       6  1884       1142    173    246    323
# 금천구       7  1348        674     51    269    354
# 노원구       8  1566        542     57    451    516
# 도봉구       9   825        238    159     42    386
# 동대문구     10  1870       1070     23    198    579
# 동작구      11  1302        544    341    103    314
# 마포구      12   980        314    118    169    379
# 서대문구     13  1254        844     50     68    292
# 서초구      14  2297       1406    157    336    398
# 성동구      15  1327        730     91    241    265
# 성북구      16  1651       1009     78    360    204
# 송파구      17  1081        529     21     68    463
# 양천구      18  2482       1843    142     30    467
# 영등포구     19  1277        495    214    195    373
# 용산구      20  2096       1368    218    112    398
# 은평구      21  2108       1138    224    278    468
# 종로구      22  1619        464    314    211    630
# 중구       23  1023        413    190     72    348
# 중랑구      24   916        509    121    177    109

# %%
con1 = df1['2015년'] >= 500
con2 = df1['2016년'] >= 500
df1[con1 & con2].index[0]
# Out:
# '강남구'

# %%
con1 = df1['2015년'] >= 300
con2 = df1['2016년'] >= 300
df1[con1 & con2].index.tolist()
# Out:
# ['강남구', '관악구', '노원구', '서초구']

# %%
con1 = df1['2015년'] >= 500
con2 = df1['2016년'] >= 500
df1[con1 | con2].index.tolist()
# Out:
# ['강남구', '관악구', '노원구', '동대문구', '종로구']
