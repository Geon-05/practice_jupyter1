# %%
pwd
# Out:
# 'C:\\Users\\go121\\practice_jupyter\\py\\데이터분석 및 시각화\\04 공공API'

# %%
import pandas as pd
import requests

# %%
def festivalApi(startdate, enddate):
    KEY = 'kzCpdqIG1LWIVrQymfmp3%2BJWFtCzoOkxDatyr3THUvTMPt0TZE2Yldkc%2BJOnhG60HUUjkjz89Y2LpIj4pvpP2w%3D%3D'
    url1 = 'http://apis.data.go.kr/B551011/KorService1/searchFestival1?serviceKey='+KEY
    url2 = '&numOfRows=1000&pageNo=1&MobileOS=ETC&MobileApp=AppTest&_type=json&listYN=Y&arrange=A'
    url3 = '&eventStartDate='+ startdate
    url4 = '&eventEndDate='+ enddate

    url = url1 + url2 + url3 + url4

    res = requests.get(url).json()
    df = pd.DataFrame(res['response']['body']['items']['item'])

    return df

dates = [
    ['20210101','20221231'],
    ['20230101','20241231']
]
res = []
for s_d, e_d in dates:
    res.append(festivalApi(s_d,e_d))
print(res)
# Out:
# [                             addr1  addr2 booktour cat1   cat2       cat3  \
# 0          경기도 고양시 일산동구 중앙로 1271-1  (장항동)           A02  A0208  A02081300
# 1              부산광역시 수영구 광안해변로 219  (광안동)           A02  A0208  A02081300
# 2                서울특별시 강북구 삼양로 561  (우이동)           A02  A0208  A02081300
# 3                충청남도 서천군 금강로 1210                  A02  A0208  A02080500
# 4    경기도 수원시 영통구 광교중앙로 140 수원컨벤션센터                  A02  A0208  A02080600
# 5   서울특별시 마포구 양화로 45 (서교동, 메세나폴리스)                  A02  A0208  A02081300
# 6              경기도 수원시 팔달구 정조로 825  (남창동)           A02  A0208  A02081300
# 7        제주특별자치도 서귀포시 성산읍 섭지코지로 95                  A02  A0208  A02081300
# 8               경상남도 밀양시 내일중앙2길 19  (내일동)           A02  A0208  A02081300
# 9          부산광역시 해운대구 APEC로 55 벡스코                  A02  A0208  A02080600
# 10         부산광역시 해운대구 APEC로 55 벡스코                  A02  A0208  A02080500
# 11              경기도 수원시 팔달구 행궁로 11  (남창동)           A02  A0208  A02081300
# 12                 경기도 양주시 권율로 594                  A02  A0208  A02081300
# 13       강원특별자치도 원주시 지정면 오크밸리1길 66                  A02  A0208  A02081300
# 14         인천광역시 연수구 청능대로 210 스퀘어원                  A02  A0208  A02081100
# 15         인천광역시 서구 봉수대로 806 (연희동)                  A02  A0208  A02080600
# 16    인천광역시 계양구 향교로 19 부평향교(지정문화재)                  A02  A0208  A02081300
# 17              서울특별시 종로구 창경궁로 185  (와룡동)           A02  A0208  A02081300
# 18            서울특별시 종로구 율곡로 99 창덕궁                  A02  A0208  A02081300
# 19               서울특별시 종로구 새문안로 97                  A02  A0208  A02081300
#
#    contentid contenttypeid     createdtime eventstartdate  ...  \
# 0    2702939            15  20210107024924       20221213  ...
# 1    2786391            15  20211206222600       20220402  ...
# 2    2592414            15  20190319004141       20220423  ...
# 3    2950881            15  20230228160055       20221208  ...
# 4    2930685            15  20220928161732       20221021  ...
# 5    3114538            15  20240422152732       20220122  ...
# 6    1805914            15  20130419192826       20211222  ...
# 7    2784074            15  20211201011454       20211108  ...
# 8    2713941            15  20210417002004       20220402  ...
# 9    2930682            15  20220928172555       20221216  ...
# 10   1762055            15  20121205012853       20221201  ...
# 4                                          마이펫페어 수원
# 5               1600-8534           매직드로잉 가족극 〈두들팝〉
# 6   수원시립공연단(031-267-1644)                무예24기 시범공연
# 7               1833-7001           미구엘 슈발리에 제주 특별전
# 8            055-354-3767          밀양 무형문화재 주말 상설공연
# 9            051-740-7705               부산 반려동물 박람회
# 10           051-803-8830             부산국제아트페어 2022
# 11           031-290-3563                  수원화성의 비밀
# 12           031-855-3010            양주 조각숲 나들이(전시)
# 13           033-730-3146   오크밸리 3D 라이팅쇼 '소나타오브라이트'
# 14          070-4260-6412             인천 영화 주간 2023
# 15           032-561-7243                   인천과학대제전
# 16           032-450-5753      지성(知性)애(愛) 빠지다, 부평향교
# 17            02-762-4868               창경궁 야간 상시관람
# 18           02-3668-2300           창덕궁 깊이보기 -심화해설-
# 19          010-6246-6918         2022 국제저작권기술 콘퍼런스
#
# [20 rows x 22 columns],                           addr1              addr2 booktour cat1   cat2  \
# 0      서울특별시 송파구 양재대로 932 (가락동)                가락몰           A02  A0207
# 1              경상북도 칠곡군 동명면 남원리  625-1 가산산성 진남문 일원           A02  A0207
# 2    경상남도 김해시 분성로261번길 35 (봉황동)                수릉원           A02  A0207
# 3        대구광역시 서구 문화로 122 (이현동)      청소년수련관 앞 이현공원           A02  A0207
# 4         인천광역시 중구 구읍로 63 (중산동)                              A02  A0207
# ..                          ...                ...      ...  ...    ...
# 995    서울특별시 종로구 동망산길 150 (숭인동)                              A02  A0207
# 996            서울특별시 마포구 홍익로 18                              A02  A0207
# 997    부산광역시 남구 분포로 66-40 (용호동)                              A02  A0207
# 998            서울특별시 종로구 삼청로 37              (세종로)           A02  A0207
# 999  전북특별자치도 정읍시 산내면 청정로 926-79                              A02  A0207
#
#           cat3 contentid contenttypeid     createdtime eventstartdate  ...  \
# 0    A02070200   3113671            15  20240415100726       20240510  ...
# 1    A02070200   3111770            15  20240326171521       20240427  ...
# 2    A02070200    694576            15  20090218020108       20241016  ...
# 3    A02070200   2397299            15  20160808200930       20240727  ...
# 4    A02070200   2986679            15  20230427173710       20240505  ...
# ..         ...       ...           ...             ...            ...  ...
# 995  A02070200   2594815            15  20190404003328       20240420  ...
# 996  A02070200   2753086            15  20211005233925       20231002  ...
# 997  A02070200   1202916            15  20110214182339       20240224  ...
# 998  A02070200   1204941            15  20110216000050       20240224  ...
# 999  A02070200   1105347            15  20101008200200       20241003  ...
#
#                                            firstimage2 cpyrhtDivCd  \
# 0    http://tong.visitkorea.or.kr/cms/resource/94/3...       Type3
# 1    http://tong.visitkorea.or.kr/cms/resource/50/3...       Type3
# 2    http://tong.visitkorea.or.kr/cms/resource/88/3...       Type3
# 3    http://tong.visitkorea.or.kr/cms/resource/70/3...       Type3
# 4    http://tong.visitkorea.or.kr/cms/resource/08/3...       Type3
# ..                                                 ...         ...
# 995  http://tong.visitkorea.or.kr/cms/resource/09/2...       Type3
# 996  http://tong.visitkorea.or.kr/cms/resource/04/3...       Type3
# 997  http://tong.visitkorea.or.kr/cms/resource/98/3...       Type3
# 998  http://tong.visitkorea.or.kr/cms/resource/67/3...       Type3
# 999  http://tong.visitkorea.or.kr/cms/resource/92/3...       Type3
#
#                mapx           mapy mlevel    modifiedtime areacode  \
# 0    127.1107693087  37.4960786971      6  20240717214406        1
# 1    128.5892257178  36.0193362823      6  20240329113623       35
# 2    128.8759611362  35.2350661468      6  20240903132102       36
# 3    128.5455030841  35.8736658721      6  20240806175831        4
# 4    126.5777264136  37.4891227900      6  20240531153501        2
# ..              ...            ...    ...             ...      ...
# 995  127.0181476492  37.5776314468      6  20240418145735        1
# 996  126.9230347562  37.5542907868      6  20240206130654        1
# 997  129.1201732372  35.1322571676      6  20240312175046        6
# 998  126.9788594400  37.5819774581      6  20240125103631        1
# 999  127.0179412789  35.5509502957      6  20240924110712       37
#
#     sigungucode            tel                  title
# 0            18   02-3435-0455         가락몰 빵축제 전국빵지자랑
# 1            22  010-2998-0103           가산산성 문화유산 야행
# 2             4   055-330-6840                 가야문화축제
# 3             6   053-663-2181             가족사랑 아이스축제
# 4            10   032-777-9891           가족의 달 어린이 축제
# ..          ...            ...                    ...
# 995          23   02-2148-1855                정순왕후문화제
# 996          13   02-3272-2334  정신건강축제 - 내 마음을 가꾸는 정원
# 997           4   051-607-4064            정월대보름 달맞이축제
# 998          23   02-3704-3114              정월대보름 한마당
# 999          13   063-539-5697             정읍 구절초 꽃축제
#
# [1000 rows x 22 columns]]

# %%
len(res)
# Out:
# 2

# %%
df=pd.concat(res,ignore_index=True)
print(df.shape)
df.head()
# Out:
# (1020, 22)
#                            addr1  addr2 booktour cat1   cat2       cat3  \
# 0        경기도 고양시 일산동구 중앙로 1271-1  (장항동)           A02  A0208  A02081300
# 1            부산광역시 수영구 광안해변로 219  (광안동)           A02  A0208  A02081300
# 2              서울특별시 강북구 삼양로 561  (우이동)           A02  A0208  A02081300
# 3              충청남도 서천군 금강로 1210                  A02  A0208  A02080500
# 4  경기도 수원시 영통구 광교중앙로 140 수원컨벤션센터                  A02  A0208  A02080600
#
#   contentid contenttypeid     createdtime eventstartdate  ...  \
# 0   2702939            15  20210107024924       20221213  ...
# 1   2786391            15  20211206222600       20220402  ...
# 2   2592414            15  20190319004141       20220423  ...
# 3   2950881            15  20230228160055       20221208  ...
# 4   2930685            15  20220928161732       20221021  ...
#
#                                          firstimage2 cpyrhtDivCd  \
# 0  http://tong.visitkorea.or.kr/cms/resource/12/2...       Type3
# 1
# 2  http://tong.visitkorea.or.kr/cms/resource/20/2...       Type3
# 3  http://tong.visitkorea.or.kr/cms/resource/63/2...       Type3
# 4
#
#              mapx           mapy mlevel    modifiedtime areacode sigungucode  \
# 0  126.7727121731  37.6595397482      6  20231130134626       31           2
# 1  129.1185505648  35.1538269450         20240326113215        6          12
# 2  127.0122877055  37.6530781245      6  20240315094017        1           3
# 3  126.7194583721  36.0271354218      6  20230914141747       34           8
# 4  127.0594632301  37.2858799237      6  20240731070936       31          13
#
#              tel                     title
# 0  031-8075-3003             고양시 트리니팅 프로젝트
# 1   051-610-4882  광안리 M(Marvelous) 드론 라이트쇼
# 2    02-901-6213  근현대사 추리여행, '사라진 열쇠를 찾아라'
# 3   041-950-5953           동물의 몸속에 기계가 있어요
# 4                                 마이펫페어 수원
#
# [5 rows x 22 columns]

# %%
df.to_csv('./관광정보.csv')
