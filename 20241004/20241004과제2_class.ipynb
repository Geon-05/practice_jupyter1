# %%
import googlemaps
import pandas as pd

# %%
class Geo_code:
    def __init__(self, search):
        KEY = 'AIzaSyDe_VheApfRF0sT9PkKV13JyoTJT8HVowU'
        gmaps = googlemaps.Client(key=KEY)
        self.addr = gmaps.geocode(search, language='ko')
        self.search = search

    def search_addr(self):
        주소 = addr[0]['formatted_address']
        return 주소

    def search_lat(self):
        위도 = addr[0]['geometry']['location']['lat']
        return 위도

    def search_lng(self):
        경도 = addr[0]['geometry']['location']['lng']
        return 경도

# %%
경복궁 = Geo_code('경복궁')

# %%
print(경복궁.search_addr())
print(경복궁.search_lat())
print(경복궁.search_lng())
# Out:
# 대한민국 서울특별시 종로구 사직로 161
# 37.579617
# 126.977041

# %%
df = pd.read_excel('./crime_2017_1.xls')
res = []
for i in df['자치구']:
    tmp = (Geo_code(i).search_addr(),Geo_code(i).search_lat(),Geo_code(i).search_lng())
    res.append(tmp)

df[['주소', '위도', '경도']] = res

display(df)
# Out:
#         자치구  살인  강도  강제추생    절도    폭력                      주소         위도  \
# 0     중부경찰서   7  10   253  1644  2143  대한민국 서울특별시 종로구 사직로 161  37.579617
# 1     중구경찰서   1   9   267  1846  2061  대한민국 서울특별시 종로구 사직로 161  37.579617
# 2    용산구경찰서   1   5   327  1346  2381  대한민국 서울특별시 종로구 사직로 161  37.579617
# 3    성동구경찰서   1   3   132  1072  1559  대한민국 서울특별시 종로구 사직로 161  37.579617
# 4    광진구경찰서   6  13   261  2220  2146  대한민국 서울특별시 종로구 사직로 161  37.579617
# 5   동대문구경찰서  11   3   165  1547  2249  대한민국 서울특별시 종로구 사직로 161  37.579617
# 6    중랑구경찰서   5   3   172  1533  2858  대한민국 서울특별시 종로구 사직로 161  37.579617
# 7    성북구경찰서   7   8   173  1344  1902  대한민국 서울특별시 종로구 사직로 161  37.579617
# 8    강북구경찰서   8   7   208  1014  2156  대한민국 서울특별시 종로구 사직로 161  37.579617
# 9    도봉구경찰서   1   3   104   633  1258  대한민국 서울특별시 종로구 사직로 161  37.579617
# 10   노원구경찰서   4   9   180  1538  2478  대한민국 서울특별시 종로구 사직로 161  37.579617
# 11   은평구경찰서   6   4   230  1387  2256  대한민국 서울특별시 종로구 사직로 161  37.579617
# ...
