# %%
# !pip install googlemaps
# Out:
# Collecting googlemaps
#   Downloading googlemaps-4.10.0.tar.gz (33 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests<3.0,>=2.20.0 in c:\users\go121\.conda\envs\edu\lib\site-packages (from googlemaps) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\go121\.conda\envs\edu\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\go121\.conda\envs\edu\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\go121\.conda\envs\edu\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\go121\.conda\envs\edu\lib\site-packages (from requests<3.0,>=2.20.0->googlemaps) (2024.8.30)
# Building wheels for collected packages: googlemaps
#   Building wheel for googlemaps (setup.py): started
#   Building wheel for googlemaps (setup.py): finished with status 'done'
#   Created wheel for googlemaps: filename=googlemaps-4.10.0-py3-none-any.whl size=40747 sha256=284f2911f1711b75ac58e3a735840cdef9a28e9dc011fbab7b1e331b8cdb9583
#   Stored in directory: c:\users\go121\appdata\local\pip\cache\wheels\4c\6a\a7\bbc6f5c200032025ee655deb5e163ce8594fa05e67d973aad6
# Successfully built googlemaps
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.10.0

# %%
# !pip install xlrd
# Out:
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.1

# %%
import googlemaps
import pandas as pd

# %%
KEY = 'AIzaSyDe_VheApfRF0sT9PkKV13JyoTJT8HVowU'

# %%
gmaps = googlemaps.Client(key=KEY)

# %%
addr = gmaps.geocode('경복궁', language='ko')

# %%
주소 = addr[0]['formatted_address']

# %%
우편번호 = addr[0]['address_components'][5]['long_name']

# %%
위도 = addr[0]['geometry']['location']['lat']

# %%
경도 = addr[0]['geometry']['location']['lng']

# %%
df = pd.read_excel('./crime_2017_1.xls')

# %%
df
# Out:
#         자치구  살인  강도  강제추생    절도    폭력
# 0     중부경찰서   7  10   253  1644  2143
# 1     중구경찰서   1   9   267  1846  2061
# 2    용산구경찰서   1   5   327  1346  2381
# 3    성동구경찰서   1   3   132  1072  1559
# 4    광진구경찰서   6  13   261  2220  2146
# 5   동대문구경찰서  11   3   165  1547  2249
# 6    중랑구경찰서   5   3   172  1533  2858
# 7    성북구경찰서   7   8   173  1344  1902
# 8    강북구경찰서   8   7   208  1014  2156
# 9    도봉구경찰서   1   3   104   633  1258
# 10   노원구경찰서   4   9   180  1538  2478
# 11   은평구경찰서   6   4   230  1387  2256
# 12  서대문구경찰서   4   1   202  1230  1676
# 13   마포구경찰서   3   8   500  2094  2673
# 14   양천구경찰서   3   3   138  1590  2148
# 15   강서구경찰서  11   4   316  1888  2916
# 16   구로구경찰서   7   8   328  1725  2827
# 17   금천구경찰서   5   5   240  1141  1874
# 18  영등포구경찰서  15   5   455  2304  3190
# 19   동작구경찰서   1   7   396  1226  1700
# 20   관악구경찰서   8   7   379  1979  3152
# 21   서초구경찰서   9  13   470  1812  2404
# 22   강남구경찰서   7  20   607  3130  3956
# 23   송파구경찰서   6   1   288  2274  3007
# 24   강동구경찰서   5  10   172  1645  2429

# %%
df['자치구']
# Out:
# 0       중부경찰서
# 1       중구경찰서
# 2      용산구경찰서
# 3      성동구경찰서
# 4      광진구경찰서
# 5     동대문구경찰서
# 6      중랑구경찰서
# 7      성북구경찰서
# 8      강북구경찰서
# 9      도봉구경찰서
# 10     노원구경찰서
# 11     은평구경찰서
# 12    서대문구경찰서
# 13     마포구경찰서
# 14     양천구경찰서
# 15     강서구경찰서
# 16     구로구경찰서
# 17     금천구경찰서
# 18    영등포구경찰서
# 19     동작구경찰서
# 20     관악구경찰서
# 21     서초구경찰서
# 22     강남구경찰서
# 23     송파구경찰서
# 24     강동구경찰서
# Name: 자치구, dtype: object
