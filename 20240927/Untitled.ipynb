# %%
pwd
# Out:
# 'C:\\Users\\zcode\\Desktop\\py\\데이터분석 및 시각화\\01판다스'

# %%
# !pip install pandas
# Out:
# ...
#   Using cached numpy-2.1.1-cp312-cp312-win_amd64.whl.metadata (59 kB)
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/11.5 MB 8.4 MB/s eta 0:00:02
#    --------- ------------------------------ 2.6/11.5 MB 7.9 MB/s eta 0:00:02
#    --------------- ------------------------ 4.5/11.5 MB 8.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.6/11.5 MB 8.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.4/11.5 MB 8.5 MB/s eta 0:00:01
#    ------------------------------------ --- 10.5/11.5 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 8.6 MB/s eta 0:00:00
# Using cached numpy-2.1.1-cp312-cp312-win_amd64.whl (12.6 MB)
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.9.2-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.3.0-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached kiwisolver-1.4.7-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# ...
#   Using cached pillow-10.4.0-cp312-cp312-win_amd64.whl.metadata (9.3 kB)
# ...
#   Using cached pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# ...
# Using cached matplotlib-3.9.2-cp312-cp312-win_amd64.whl (7.8 MB)
# Using cached contourpy-1.3.0-cp312-cp312-win_amd64.whl (218 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ----------------------- ---------------- 1.3/2.2 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 5.9 MB/s eta 0:00:00
# Using cached kiwisolver-1.4.7-cp312-cp312-win_amd64.whl (55 kB)
# Using cached pillow-10.4.0-cp312-cp312-win_amd64.whl (2.6 MB)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# %%
df = pd.read_csv('./data/house_price_clean.csv')
print(df.shape)
df.head()
# Out:
# (3293, 5)
#    지역             규모    연도   월   분양가
# 0  서울          60㎡이하  2015  10  5652
# 1  서울    60㎡초과 85㎡이하  2015  10  5882
# 2  서울   85㎡초과 102㎡이하  2015  10  5721
# 3  서울         102㎡초과  2015  10  5879
# 4  인천          60㎡이하  2015  10  3488

# %%
plt.figure(figsize=(15, 5))
df.groupby(['지역','규모'])['분양가'].min().plot(kind='bar')
# Out:
# <Axes: xlabel='지역,규모'>

# %%
list(df.groupby('지역'))
# Out:
# [('강원',
#         지역             규모    연도   월   분양가
#   33    강원          60㎡이하  2015  10  2286
#   34    강원    60㎡초과 85㎡이하  2015  10  2212
#   35    강원   85㎡초과 102㎡이하  2015  10  2061
#   36    강원         102㎡초과  2015  10  2171
#   97    강원          60㎡이하  2015  11  2292
#   ...   ..            ...   ...  ..   ...
#   3209  강원         102㎡초과  2020   1  3891
#   3265  강원          60㎡이하  2020   2  2560
#   3266  강원    60㎡초과 85㎡이하  2020   2  2501
#   3267  강원   85㎡초과 102㎡이하  2020   2  3329
#   3268  강원         102㎡초과  2020   2  3906
#
#   [204 rows x 5 columns]),
#  ('경기',
#         지역             규모    연도   월   분양가
#   8     경기          60㎡이하  2015  10  3126
#   9     경기    60㎡초과 85㎡이하  2015  10  3239
#   10    경기   85㎡초과 102㎡이하  2015  10  3496
#   11    경기         102㎡초과  2015  10  3680
#   72    경기          60㎡이하  2015  11  3079
#   ...   ..            ...   ...  ..   ...
#   3186  경기         102㎡초과  2020   1  5204
#   3242  경기          60㎡이하  2020   2  4918
# ...

# %%
df.groupby(['지역','규모'])['분양가'].min()
# Out:
# 지역  규모
# 강원  102㎡초과          2171
#     60㎡이하           2017
#     60㎡초과 85㎡이하     2070
#     85㎡초과 102㎡이하    2012
# 경기  102㎡초과          3611
#                     ...
# 충남  85㎡초과 102㎡이하    2523
# 충북  102㎡초과          2221
#     60㎡이하           1915
#     60㎡초과 85㎡이하     1983
#     85㎡초과 102㎡이하    1868
# Name: 분양가, Length: 68, dtype: int64

# %%
df.groupby(['지역','규모'])[['분양가']].min()
# Out:
#                   분양가
# 지역 규모
# 강원 102㎡초과        2171
#    60㎡이하         2017
#    60㎡초과 85㎡이하   2070
#    85㎡초과 102㎡이하  2012
# 경기 102㎡초과        3611
# ...               ...
# 충남 85㎡초과 102㎡이하  2523
# 충북 102㎡초과        2221
#    60㎡이하         1915
#    60㎡초과 85㎡이하   1983
#    85㎡초과 102㎡이하  1868
#
# [68 rows x 1 columns]

# %%
plt.figure(figsize=(15, 5))
df.groupby(['지역','규모'])['분양가'].min().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='지역,규모'>

# %%
df1 = pd.read_csv('./data/train.csv')

# %%
print(df1.shape)
df1.head()
# Out:
# (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
df1.groupby('Survived')['Age'].describe()
# Out:
#           count       mean        std   min   25%   50%   75%   max
# Survived
# 0         424.0  30.626179  14.172110  1.00  21.0  28.0  39.0  74.0
# 1         290.0  28.343690  14.950952  0.42  19.0  28.0  36.0  80.0

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df1.isnull().sum() / len(df1) * 100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
df1.isnull().sum() / df1.shape[0] * 100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df1['Sex'].value_counts() / len(df1) * 100
# Out:
# Sex
# male      64.758698
# female    35.241302
# Name: count, dtype: float64

# %%
df1.groupby(['Survived','Sex'])['Age'].mean()
# Out:
# Survived  Sex
# 0         female    25.046875
#           male      31.618056
# 1         female    28.847716
#           male      27.276022
# Name: Age, dtype: float64

# %%
df1.groupby(['Survived','Sex'])['Age'].mean().unstack(0)
# Out:
# Survived          0          1
# Sex
# female    25.046875  28.847716
# male      31.618056  27.276022

# %%
tmp = df1.groupby(['Survived','Sex'])['Age'].mean().unstack(0)

# %%
tmp / tmp.sum() * 100
# Out:
# Survived          0          1
# Sex
# female    44.201722  51.400205
# male      55.798278  48.599795

# %%
df.head()
# Out:
#    지역             규모    연도   월   분양가
# 0  서울          60㎡이하  2015  10  5652
# 1  서울    60㎡초과 85㎡이하  2015  10  5882
# 2  서울   85㎡초과 102㎡이하  2015  10  5721
# 3  서울         102㎡초과  2015  10  5879
# 4  인천          60㎡이하  2015  10  3488

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df1.groupby(['Survived','Embarked'])['PassengerId'].count()
# Out:
# Survived  Embarked
# 0         C            75
#           Q            47
#           S           427
# 1         C            93
#           Q            30
#           S           217
# Name: PassengerId, dtype: int64

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df3=pd.read_csv('./data/cctv_in_seoul.csv')
df3.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379     99    155    377
# 2  강북구   831        369    120    138    204
# 3  강서구   911        388    258    184     81
# 4  관악구  2109        846    260    390    613

# %%
df3['구분'] = pd.cut(df3['소계'],bins=3,labels=['하','중','상'])

# %%
df3
# Out:
#      기관명    소계  2013년도 이전  2014년  2015년  2016년 구분
# 0    강남구  3238       1292    430    584    932  상
# 1    강동구  1010        379     99    155    377  하
# 2    강북구   831        369    120    138    204  하
# 3    강서구   911        388    258    184     81  하
# 4    관악구  2109        846    260    390    613  중
# 5    광진구   878        573     78     53    174  하
# 6    구로구  1884       1142    173    246    323  중
# 7    금천구  1348        674     51    269    354  하
# 8    노원구  1566        542     57    451    516  하
# 9    도봉구   825        238    159     42    386  하
# 10  동대문구  1870       1070     23    198    579  중
# 11   동작구  1302        544    341    103    314  하
# 12   마포구   980        314    118    169    379  하
# 13  서대문구  1254        844     50     68    292  하
# 14   서초구  2297       1406    157    336    398  중
# 15   성동구  1327        730     91    241    265  하
# 16   성북구  1651       1009     78    360    204  중
# 17   송파구  1081        529     21     68    463  하
# ...

# %%
df3.groupby('구분').mean(numeric_only=True)
# Out:
# C:\Users\zcode\AppData\Local\Temp\ipykernel_25760\2619911176.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df3.groupby('구분').mean(numeric_only=True)
#              소계    2013년도 이전       2014년       2015년       2016년
# 구분
# 하   1134.250000   500.312500  142.625000  162.250000  329.062500
# 중   2002.142857  1139.857143  161.857143  274.285714  426.142857
# 상   2860.000000  1567.500000  286.000000  307.000000  699.500000

# %%
df3.sum(numeric_only=True)
# Out:
# 소계           37883
# 2013년도 이전    19119
# 2014년         3987
# 2015년         5130
# 2016년         9647
# dtype: int64

# %%
df3.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년 구분
# 0  강남구  3238       1292    430    584    932  상
# 1  강동구  1010        379     99    155    377  하
# 2  강북구   831        369    120    138    204  하
# 3  강서구   911        388    258    184     81  하
# 4  관악구  2109        846    260    390    613  중

# %%
df3.groupby('구분')[['2015년','2016년']].agg(['min','max','mean']).T
# Out:
# C:\Users\zcode\AppData\Local\Temp\ipykernel_25760\1420785639.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df3.groupby('구분')[['2015년','2016년']].agg(['min','max','mean']).T
# 구분                 하           중      상
# 2015년 min    42.0000  112.000000   30.0
#       max   451.0000  390.000000  584.0
#       mean  162.2500  274.285714  307.0
# 2016년 min    81.0000  204.000000  467.0
#       max   630.0000  613.000000  932.0
#       mean  329.0625  426.142857  699.5
