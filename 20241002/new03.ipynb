# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

df = sns.load_dataset('titanic')
print(df.shape)
df.head()
# Out:
# (891, 15)
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df[['sibsp','parch']]
# Out:
#      sibsp  parch
# 0        1      0
# 1        1      0
# 2        0      0
# 3        1      0
# 4        0      0
# ..     ...    ...
# 886      0      0
# 887      0      0
# 888      1      2
# 889      0      0
# 890      0      0
#
# [891 rows x 2 columns]

# %%
df.groupby(['parch','sibsp'])['survived'].count()
# Out:
# parch  sibsp
# 0      0        537
#        1        123
#        2         16
#        3          2
# 1      0         38
#        1         57
#        2          7
#        3          7
#        4          9
# 2      0         29
#        1         19
#        2          4
#        3          7
#        4          9
#        5          5
#        8          7
# 3      0          1
#        1          3
#        2          1
# 4      0          1
#        1          3
# 5      0          2
#        1          3
# 6      1          1
# Name: survived, dtype: int64

# %%
df['alone'].sum()
# Out:
# np.int64(537)

# %%
cols = ['survived', 'age', 'sibsp', 'parch', 'adult_male', 'alone']

# %%
df[cols].corr()
# Out:
#             survived       age     sibsp     parch  adult_male     alone
# survived    1.000000 -0.077221 -0.035322  0.081629   -0.557080 -0.203367
# age        -0.077221  1.000000 -0.308247 -0.189119    0.280328  0.198270
# sibsp      -0.035322 -0.308247  1.000000  0.414838   -0.253586 -0.584471
# parch       0.081629 -0.189119  0.414838  1.000000   -0.349943 -0.583398
# adult_male -0.557080  0.280328 -0.253586 -0.349943    1.000000  0.404744
# alone      -0.203367  0.198270 -0.584471 -0.583398    0.404744  1.000000

# %%
df[cols].corr().sort_values('survived')
# Out:
#             survived       age     sibsp     parch  adult_male     alone
# adult_male -0.557080  0.280328 -0.253586 -0.349943    1.000000  0.404744
# alone      -0.203367  0.198270 -0.584471 -0.583398    0.404744  1.000000
# age        -0.077221  1.000000 -0.308247 -0.189119    0.280328  0.198270
# sibsp      -0.035322 -0.308247  1.000000  0.414838   -0.253586 -0.584471
# parch       0.081629 -0.189119  0.414838  1.000000   -0.349943 -0.583398
# survived    1.000000 -0.077221 -0.035322  0.081629   -0.557080 -0.203367

# %%
df.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
# 1. 각 class별 who의 인원을 그래프로 그리기
sns.countplot(x='class', data=df, hue='who')
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
x = np.random.random(100)

# %%
sns.displot(x)

# %%
sns.displot(x, kde=True)

# %%
sns.distplot(x, hist=False)
# Out:
# C:\Users\go121\AppData\Local\Temp\ipykernel_21476\4021714020.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, hist=False)
# <Axes: ylabel='Density'>

# %%
sns.distplot(x, rug=True)
# Out:
# C:\Users\go121\AppData\Local\Temp\ipykernel_21476\3348672814.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x, rug=True)
# <Axes: ylabel='Density'>

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
sns.pairplot(data=df)

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, kind='reg')

# %%
sns.pairplot(df, kind='reg', diag_kind='kde')

# %%
sns.pairplot(df, hue='sex')

# %%
sns.pairplot(df, hue='size')

# %%
sns.pairplot(df, kind='reg', hue='sex')

# %%
df['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
sns.pairplot(df, height=5, aspect=0.5)

# %%
sns.lmplot(x='total_bill', y='tip', data=df)

# %%
sns.lmplot(x='total_bill', y='tip', data=df, hue='sex', row='day', col='time')

# %%
sns.lmplot(x='total_bill', y='tip', data=df, row='day', col='time')

# %%
sns.jointplot(x='total_bill', y='tip', data=df)

# %%
sns.jointplot(x='total_bill', y='tip', data=df, kind='reg')

# %%
sns.jointplot(x='total_bill', y='tip', data=df, kind='hex')

# %%
sns.jointplot(x='total_bill', y='tip', data=df, kind='hist')
