# %%
import requests
import pandas as pd

# %%
url ='http://apis.data.go.kr/B551011/KorService1/searchFestival1?serviceKey=kzCpdqIG1LWIVrQymfmp3%2BJWFtCzoOkxDatyr3THUvTMPt0TZE2Yldkc%2BJOnhG60HUUjkjz89Y2LpIj4pvpP2w%3D%3D&numOfRows=10&pageNo=1&MobileOS=ETC&MobileApp=AppTest&_type=json&listYN=Y&arrange=A&eventStartDate=20170901'

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'response': {'header': {'resultCode': '0000', 'resultMsg': 'OK'},
#   'body': {'items': {'item': [{'addr1': '서울특별시 송파구 양재대로 932 (가락동)',
#       'addr2': '가락몰',
#       'booktour': '',
#       'cat1': 'A02',
#       'cat2': 'A0207',
#       'cat3': 'A02070200',
#       'contentid': '3113671',
#       'contenttypeid': '15',
#       'createdtime': '20240415100726',
#       'eventstartdate': '20240510',
#       'eventenddate': '20240512',
#       'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/94/3332394_image2_1.jpg',
#       'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/94/3332394_image3_1.jpg',
#       'cpyrhtDivCd': 'Type3',
#       'mapx': '127.1107693087',
#       'mapy': '37.4960786971',
#       'mlevel': '6',
#       'modifiedtime': '20240717214406',
#       'areacode': '1',
#       'sigungucode': '18',
#       'tel': '02-3435-0455',
#       'title': '가락몰 빵축제 전국빵지자랑'},
#      {'addr1': '경상북도 칠곡군 동명면 남원리',
#       'addr2': '625-1 가산산성 진남문 일원',
# ...

# %%
type(response.json())
# Out:
# dict

# %%
response.text
# Out:
# '{"response": {"header":{"resultCode":"0000","resultMsg":"OK"},"body": {"items": {"item":[{"addr1":"서울특별시 송파구 양재대로 932 (가락동)","addr2":"가락몰","booktour":"","cat1":"A02","cat2":"A0207","cat3":"A02070200","contentid":"3113671","contenttypeid":"15","createdtime":"20240415100726","eventstartdate":"20240510","eventenddate":"20240512","firstimage":"http://tong.visitkorea.or.kr/cms/resource/94/3332394_image2_1.jpg","firstimage2":"http://tong.visitkorea.or.kr/cms/resource/94/3332394_image3_1.jpg","cpyrhtDivCd":"Type3","mapx":"127.1107693087","mapy":"37.4960786971","mlevel":"6","modifiedtime":"20240717214406","areacode":"1","sigungucode":"18","tel":"02-3435-0455","title":"가락몰 빵축제 전국빵지자랑"},{"addr1":"경상북도 칠곡군 동명면 남원리","addr2":"625-1 가산산성 진남문 일원","booktour":"","cat1":"A02","cat2":"A0207","cat3":"A02070200","contentid":"3111770","contenttypeid":"15","createdtime":"20240326171521","eventstartdate":"20240427","eventenddate":"20240428","firstimage":"http://tong.visitkorea.or.kr/cms/resource/50/3111750
# ...

# %%
type(response)
# Out:
# requests.models.Response

# %%
response = response.json()

# %%
response
# Out:
# {'response': {'header': {'resultCode': '0000', 'resultMsg': 'OK'},
#   'body': {'items': {'item': [{'addr1': '서울특별시 송파구 양재대로 932 (가락동)',
#       'addr2': '가락몰',
#       'booktour': '',
#       'cat1': 'A02',
#       'cat2': 'A0207',
#       'cat3': 'A02070200',
#       'contentid': '3113671',
#       'contenttypeid': '15',
#       'createdtime': '20240415100726',
#       'eventstartdate': '20240510',
#       'eventenddate': '20240512',
#       'firstimage': 'http://tong.visitkorea.or.kr/cms/resource/94/3332394_image2_1.jpg',
#       'firstimage2': 'http://tong.visitkorea.or.kr/cms/resource/94/3332394_image3_1.jpg',
#       'cpyrhtDivCd': 'Type3',
#       'mapx': '127.1107693087',
#       'mapy': '37.4960786971',
#       'mlevel': '6',
#       'modifiedtime': '20240717214406',
#       'areacode': '1',
#       'sigungucode': '18',
#       'tel': '02-3435-0455',
#       'title': '가락몰 빵축제 전국빵지자랑'},
#      {'addr1': '경상북도 칠곡군 동명면 남원리',
#       'addr2': '625-1 가산산성 진남문 일원',
# ...

# %%
response.keys()
# Out:
# dict_keys(['response'])

# %%
response['response']['body']['totalCount']
# Out:
# 1574

# %%
items = response['response']['body']['items']['item']

# %%
len(items)
# Out:
# 10

# %%
df = pd.DataFrame(response['response']['body']['items']['item'])
df
# Out:
#                         addr1              addr2 booktour cat1   cat2  \
# 0    서울특별시 송파구 양재대로 932 (가락동)                가락몰           A02  A0207
# 1            경상북도 칠곡군 동명면 남원리  625-1 가산산성 진남문 일원           A02  A0207
# 2  경상남도 김해시 분성로261번길 35 (봉황동)                수릉원           A02  A0207
# 3      대구광역시 서구 문화로 122 (이현동)      청소년수련관 앞 이현공원           A02  A0207
# 4       인천광역시 중구 구읍로 63 (중산동)                              A02  A0207
# 5            제주특별자치도 서귀포시 대정읍    가파로 67번길 가파도 일원           A02  A0207
# 6            경상남도 거창군 신원면 덕산리               산 57           A02  A0207
# 7                경상남도 거창군 신원면         거창군 감악산 정상           A02  A0207
# 8            충청남도 논산시 강경읍 중앙리               53-7           A02  A0207
# 9         충청남도 논산시 강경읍 금백로 45                              A02  A0207
#
#         cat3 contentid contenttypeid     createdtime eventstartdate  ...  \
# 0  A02070200   3113671            15  20240415100726       20240510  ...
# ...

# %%
for i in items:
    print('주소 :',i['addr1'])
    print(' '*6,i['addr2'])
    print('행사명 :',i['title'])
    print('='*60)
# Out:
# 주소 : 서울특별시 송파구 양재대로 932 (가락동)
#        가락몰
# 행사명 : 가락몰 빵축제 전국빵지자랑
# ...
# 주소 : 경상북도 칠곡군 동명면 남원리
#        625-1 가산산성 진남문 일원
# 행사명 : 가산산성 문화유산 야행
# ...
# 주소 : 경상남도 김해시 분성로261번길 35 (봉황동)
#        수릉원
# 행사명 : 가야문화축제
# ...
# 주소 : 대구광역시 서구 문화로 122 (이현동)
#        청소년수련관 앞 이현공원
# 행사명 : 가족사랑 아이스축제
# ...
# 주소 : 인천광역시 중구 구읍로 63 (중산동)
#
# 행사명 : 가족의 달 어린이 축제
# ...
# 주소 : 제주특별자치도 서귀포시 대정읍
#        가파로 67번길 가파도 일원
# 행사명 : 가파도청보리축제
# ...
# 주소 : 경상남도 거창군 신원면 덕산리
#        산 57
# 행사명 : 감악산 꽃별 여행
# ...
# 주소 : 경상남도 거창군 신원면
#        거창군 감악산 정상
# 행사명 : 감악산 해맞이 행사
# ...
# 주소 : 충청남도 논산시 강경읍 중앙리
#        53-7
# 행사명 : 강경 문화유산 야행
# ...
# 주소 : 충청남도 논산시 강경읍 금백로 45
#
# 행사명 : 강경젓갈축제
# ...
