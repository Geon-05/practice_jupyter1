# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# %%
df = sns.load_dataset('iris')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
print(df.shape)
df.head()
df.dtypes
# Out:
# (150, 5)
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
sns.pairplot(df, hue='species')

# %%
'''
판다스 -> 시각화

[데이터수집]
- 공공 api / 민간 api(구글, 네이버, ...) (Open API)
-> 지도그리기

- 크롤링 (뷰티플숍, 셀레니움)

서버 막힌것은 뚫는 방법(우회하는) 구글링/gpt이용!
'''
# Out:
# '\n판다스 -> 시각화\n\n[데이터수집]\n- 공공 api / 민간 api(구글, 네이버, ...) (Open API)\n-> 지도그리기\n\n- 크롤링 (뷰티플숍, 셀레니움)\n\n서버 막힌것은 뚫는 방법(우회하는) 구글링/gpt이용!\n'

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
'''
2번 문제 : 데이터 구조 파악하기
문제) 데이터셋의 첫 5행을 출력하고, 데이터의 구조를 파악하세요.
'''
display(df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
'''
3번 문제 : 데이터 요약 정보 확인하기
문제) 데이터셋의 요약 정보를 확인하세요.
'''
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %%
'''
4번 문제 : 기초 통계량 확인하기
문제) 각 열의 기초 통계량(평균, 표준편차, 최솟값, 최댓값 등)을 출력하세요.
'''
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
'''
5번 문제 : 특정 열 선택하기
문제) 'Sepal Length' 열만 선택하여 출력하세요.
'''
df['sepal_length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
'''
6번 문제 : 조건에 맞는 데이터 필터링하기
문제) 'Species'가 'Iris-setosa'인 행들만 선택하여 새로운 데이터프레임을 만드세요.
'''
iris_setosa = df[df['species']=='setosa']

# %%
'''
7번 문제 : 그룹별 통계량 계산하기
문제) 각 품종('Species')별로 'Sepal Length'의 평균을 계산하세요.
'''
df.groupby('species')['sepal_length'].mean()
# Out:
# species
# setosa        5.006
# versicolor    5.936
# virginica     6.588
# Name: sepal_length, dtype: float64
