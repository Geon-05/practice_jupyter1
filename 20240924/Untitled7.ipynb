# %%
pwd
# Out:
# 'C:\\Users\\zcode\\Documents\\py\\2차'

# %%
#!pip install pillow

# %%
#!pip install numpy

# %%
import os
# from os import listdir
from glob import glob
from PIL import Image
import numpy as np

# %%
a = [1,2,3,4] #[2,4,6,8]
res = []
for i in a:
    res.append(i*2)
print(res)
# Out:
# [2, 4, 6, 8]

# %%
a = [1,2,3,4]
b = np.array(a)
print(a, type(a))
print(b, type(b))
print(b*2)
# Out:
# [1, 2, 3, 4] <class 'list'>
# [1 2 3 4] <class 'numpy.ndarray'>
# [2 4 6 8]

# %%
os.listdir('./images/')
# Out:
# ['강아지1.jpg',
#  '강아지10.jpg',
#  '강아지2.jpg',
#  '강아지3.jpg',
#  '강아지4.jpg',
#  '강아지5.jpg',
#  '강아지6.jpg',
#  '강아지7.jpg',
#  '강아지8.jpg',
#  '강아지9.jpg',
#  '고양이1.jpg',
#  '고양이2.jpg',
#  '고양이3.jpg',
#  '고양이4.jpg',
#  '고양이5.jpg',
#  '고양이6.jpg']

# %%
img = Image.open('./images/강아지10.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=599x400>

# %%
np.array(img)
# Out:
# array([[[188, 169, 152],
#         [187, 168, 151],
#         [185, 166, 149],
#         ...,
#         [173, 157, 141],
#         [170, 154, 138],
#         [168, 152, 136]],
#
#        [[189, 170, 153],
#         [188, 169, 152],
#         [187, 168, 151],
#         ...,
#         [173, 157, 141],
#         [171, 155, 139],
#         [169, 153, 137]],
#
#        [[190, 171, 154],
#         [189, 170, 153],
#         [188, 169, 152],
#         ...,
#         [173, 156, 140],
#         [171, 154, 138],
#         [171, 154, 138]],
#
#        ...,
#
#        [[183, 162, 135],
#         [181, 160, 133],
#         [179, 157, 133],
#         ...,
#         [178, 159, 142],
#         [174, 155, 138],
#         [173, 154, 137]],
#
#        [[188, 167, 138],
#         [186, 165, 138],
#         [185, 163, 139],
#         ...,
#         [171, 154, 138],
#         [174, 157, 141],
#         [177, 160, 144]],
#
#        [[191, 170, 141],
#         [191, 170, 141],
#         [192, 170, 146],
# ...

# %%
file_names = glob('./images/*.jpg')
# print(file_names)
# Out:
# ['./images\\강아지1.jpg', './images\\강아지10.jpg', './images\\강아지2.jpg', './images\\강아지3.jpg', './images\\강아지4.jpg', './images\\강아지5.jpg', './images\\강아지6.jpg', './images\\강아지7.jpg', './images\\강아지8.jpg', './images\\강아지9.jpg', './images\\고양이1.jpg', './images\\고양이2.jpg', './images\\고양이3.jpg', './images\\고양이4.jpg', './images\\고양이5.jpg', './images\\고양이6.jpg']

# %%
a = [1,2,3.0,4]
b = np.array(a)
print(b) #자동으로 모두 실수화
# Out:
# [1. 2. 3. 4.]

# %%
a = [1,2,3,4]
b = np.array(a)
print(b) #모든 타입은 같다
# Out:
# [1 2 3 4]

# %%
a = [1,2,3,"4"]
b = np.array(a)
print(b) #자동으로 모두 문자열화
# Out:
# ['1' '2' '3' '4']

# %%
a=[
    [1,2,3],
    [4,5,None]
]
b = np.array(a)
print(b)
# Out:
# [['1' '2' '3']
#  ['4' '5' '-']]

# %%
a = [
    [1,1,1],
    [2,2,2]
]
s = 3
b = [1,2]
b2 = [1,2,3]
b3 = [
    [1],
    [2]
]

arr = np.array(a)
print(arr*s)
print('-'*20)
# print(arr*b) -> 에러 ValueError: operands could not be broadcast together with shapes (2,3) (2,)
# 축을 맞춰야 에러가 나지 않는다.
print(arr*b2)
print(arr*b3)
# Out:
# [[3 3 3]
#  [6 6 6]]
# --------------------
# [[1 2 3]
#  [2 4 6]]
# [[1 1 1]
#  [4 4 4]]
